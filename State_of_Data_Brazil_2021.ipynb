# %% [markdown]
# <a href="https://colab.research.google.com/github/brayannmb/state_of_data_brazil_project/blob/main/State_of_Data_Brazil_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

pd.set_option('display.max_columns', None) #display all columns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/brayannmb/state_of_data_brazil_project/main/state_of_data.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (47) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# Com imenso prazer estou realizando essa análise exploratória de dados relacionado ao mercado de Ciência de Dadosno Brasil. Sou muito grato a comunidade de dados, pois através da criação de portfólio, posts e projetos eu consegui a minha primeira oportunidade como Cientista de Dados.
# Agradeço em especial a comunidade do Data Hackers.

# %% [markdown]
# Durante esta análise eu vou seguir como base as informações contidas no site do [State of Data Brazil](https://www.stateofdata.com.br/challenge) e no site do [Kaggle](https://www.kaggle.com/datasets/datahackers/state-of-data-2021), de onde foi extraído os dados.

# %% [markdown]
# #Let's go!
#
# Primeiramente eu vou fazer uma visualização rápida de como estão os dados, visualizando as 5 primeiras, as 5 últimas e 10 aleatórias linha do conjunto de dados.
#
# **Será que nesta análises irei encontrar dados para me tornar o Cientista de Dados sexy e com salário de 25k/Mês? (risos)**

# %%
#visualizando as 5 primeiras linhas
df.head(1)
# Out:
#                        ('P0', 'id')  ('P1_a ', 'Idade')  \
# 0  qkx4q0ei90wcjxnqkx4q0j3xgf0zn13s                38.0
#
#   ('P1_a_a ', 'Faixa idade') ('P1_b ', 'Genero')  \
# 0                      35-39           Masculino
#
#   ('P1_e ', 'Estado onde mora') ('P1_e_a ', 'uf onde mora')  \
# 0                    Ceará (CE)                          CE
#
#   ('P1_e_b ', 'Regiao onde mora') ('P1_g_b ', 'Regiao de origem')  \
# 0                        Nordeste                             NaN
#
#    ('P1_g_c ', 'Mudou de Estado?') ('P1_h ', 'Nivel de Ensino')  \
# 0                                0                Pós-graduação
#
#   ('P1_i ', 'Área de Formação')  \
# 0              Química / Física
#
#   ('P2_a ', 'Qual sua situação atual de trabalho?') ('P2_b ', 'Setor')  \
# 0                                   Empregado (CLT)          Marketing
#
#   ('P2_c ', 'Numero de Funcionarios')  ('P2_d ', 'Gestor?')  \
# 0                        de 101 a 500                   1.0
#
#   ('P2_e ', 'Cargo como Gestor') ('P2_f ', 'Cargo Atual') ('P2_g ', 'Nivel')  \
# 0         Supervisor/Coordenador                      NaN                NaN
#
#       ('P2_h ', 'Faixa salarial')  \
# 0  de R$ 4.001/mês a R$ 6.000/mês
#
#   ('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')  \
# 0                                    Mais de 10 anos
#
#   ('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')  \
# 0  Não tive experiência na área de TI/Engenharia ...
#
#    ('P2_k ', 'Você está satisfeito na sua empresa atual?')  \
# 0                                                1.0
#
#   ('P2_l ', 'Qual o principal motivo da sua insatisfação com a empresa atual?')  \
# 0                                                NaN
#
#    ('P2_l_a ', 'Falta de oportunidade de crescimento no emprego atual')  \
# 0                                                NaN
#
#    ('P2_l_b ', 'Salário atual não corresponde ao mercado')  \
# 0                                                NaN
#
#    ('P2_l_c ', 'Não tenho uma boa relação com meu líder/gestor')  \
# 0                                                NaN
#
#    ('P2_l_d ', 'Gostaria de trabalhar em em outra área de atuação')  \
# 0                                                NaN
#
#    ('P2_l_e ', 'Gostaria de receber mais benefícios')  \
# 0                                                NaN
#
#    ('P2_l_f ', 'O clima de trabalho/ambiente não é bom')  \
# 0                                                NaN
#
#    ('P2_l_g ', 'Falta de maturidade analítica na empresa')  \
# 0                                                NaN
#
#   ('P2_m ', 'Você participou de entrevistas de emprego nos últimos 6 meses?')  \
# 0               Sim, fui aprovado e mudei de emprego
#
#   ('P2_n ', 'Você pretende mudar de emprego nos próximos 6 meses?')  \
# 0  Estou em busca de oportunidades dentro ou fora...
#
#   ('P2_o ', 'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?')  \
# 0                                         Benefícios
#
#    ('P2_o_a ', 'Remuneração/Salário')  ('P2_o_b ', 'Benefícios')  \
# 0                                 0.0                        1.0
#
#    ('P2_o_c ', 'Propósito do trabalho e da empresa')  \
# 0                                                0.0
#
#    ('P2_o_d ', 'Flexibilidade de trabalho remoto')  \
# 0                                              0.0
#
#    ('P2_o_e ', 'Ambiente e clima de trabalho')  \
# 0                                          0.0
#
#    ('P2_o_f ', 'Oportunidade de aprendizado e trabalhar com referências na área')  \
# 0                                                0.0
#
#    ('P2_o_g ', 'Plano de carreira e oportunidades de crescimento profissional')  \
# 0                                                0.0
#
#    ('P2_o_h ', 'Maturidade da empresa em termos de tecnologia e dados')  \
# 0                                                0.0
#
#    ('P2_o_i ', 'Qualidade dos gestores e líderes')  \
# 0                                              0.0
#
#    ('P2_o_j ', 'Reputação que a empresa tem no mercado')  \
# 0                                                0.0
#
#   ('P2_q ', 'Atualmente qual a sua forma de trabalho?')  \
# 0                             Modelo 100% presencial
#
#   ('P2_r ', 'Qual a forma de trabalho ideal para você?')  \
# 0  Modelo híbrido com dias fixos de trabalho pres...
#
#   ('P2_s ', 'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?')  \
# 0  Vou aceitar e retornar ao modelo 100% presencial.
#
#   ('P3_a ', 'Qual o número aproximado de pessoas que atuam com dados na sua empresa hoje?')  \
# 0                                             4 - 10
#
#   ('P3_b ', 'Quais desses papéis/cargos fazem parte do time (ou chapter) de dados da sua empresa?')  \
# 0               Analista de Business Intelligence/BI
#
#    ('P3_b_a ', 'Analytics Engineer')  \
# 0                                0.0
#
#    ('P3_b_b ', 'Engenharia de Dados/Data Engineer')  \
# 0                                               0.0
#
#    ('P3_b_c ', 'Analista de Dados/Data Analyst')  \
# 0                                            0.0
#
#    ('P3_b_d ', 'Cientista de Dados/Data Scientist')  \
# 0                                               0.0
#
#    ('P3_b_e ', 'Database Administrator/DBA')  \
# 0                                        0.0
#
#    ('P3_b_f ', 'Analista de Business Intelligence/BI')  \
# 0                                                1.0
#
#    ('P3_b_g ', 'Arquiteto de Dados/Data Architect')  \
# 0                                               0.0
#
#    ('P3_b_h ', 'Data Product Manager/DPM')  ('P3_b_i ', 'Business Analyst')  \
# 0                                      0.0                              0.0
#
#   ('P3_c ', 'Quais dessas responsabilidades fazem parte da sua rotina atual de trabalho como gestor?')  \
# 0  Sou gestor da equipe responsável pela entrega ...
#
#    ('P3_c_a ', 'Pensar na visão de longo prazo de dados da empresa e fortalecimento da cultura analítica da companhia.')  \
# 0                                                0.0
#
#    ('P3_c_b ', 'Organização de treinamentos e iniciativas com o objetivo de aumentar a maturidade analítica das áreas de negócios.')  \
# 0                                                0.0
#
#    ('P3_c_c ', 'Atração, seleção e contratação de talentos para o time de dados.')  \
# 0                                                0.0
#
#    ('P3_c_d ', 'Decisão sobre contratação de ferramentas e tecnologias relacionadas a dados.')  \
# 0                                                0.0
#
#    ('P3_c_e ', 'Sou gestor da equipe responsável pela engenharia de dados e por manter o Data Lake da empresa como fonte única dos dados, garantindo a qualidade e confiabilidade da informação.')  \
# 0                                                0.0
#
#    ('P3_c_f ', 'Sou gestor da equipe responsável pela entrega de dados, estudos, relatórios e dashboards para as áreas de negócio da empresa.')  \
# 0                                                1.0
#
#    ('P3_c_g ', 'Sou gestor da equipe responsável por iniciativas e projetos envolvendo Inteligência Artificial e Machine Learning.')  \
# 0                                                0.0
#
#    ('P3_c_h ', 'Apesar de ser gestor ainda atuo na parte técnica, construindo soluções/análises/modelos etc.')  \
# 0                                                0.0
#
#    ('P3_c_i ', 'Gestão de projetos de dados, cuidando das etapas, equipes envolvidas, atingimento dos objetivos etc.')  \
# 0                                                0.0
#
#    ('P3_c_j ', 'Gestão de produtos de dados, cuidando da visão dos produtos, backlog, feedback de usuários etc.')  \
# 0                                                0.0
#
#    ('P3_c_k ', 'Gestão de pessoas, apoio no desenvolvimento das pessoas, evolução de carreira')  \
# 0                                                0.0
#
#   ('P3_d ', 'Quais são os 3 maiores desafios que você tem como gestor no atual momento?')  \
# 0  Garantir a manutenção dos projetos e modelos e...
#
#    ('P3_d_ ', 'a Contratar novos talentos.')  ('P3_d_ ', 'b Reter talentos.')  \
# 0                                        0.0                              0.0
#
#    ('P3_d_ ', 'c Convencer a empresa a aumentar os investimentos na área de dados.')  \
# 0                                                0.0
#
#    ('P3_d_ ', 'd Gestão de equipes no ambiente remoto.')  \
# 0                                                0.0
#
#    ('P3_d_ ', 'e Gestão de projetos envolvendo áreas multidisciplinares da empresa.')  \
# 0                                                0.0
#
#    ('P3_d_ ', 'f Organizar as informações e garantir a qualidade e confiabilidade.')  \
# 0                                                0.0
#
#    ('P3_d_ ', 'g Conseguir processar e armazenar um alto volume de dados.')  \
# 0                                                0.0
#
#    ('P3_d_ ', 'h Conseguir gerar valor para as áreas de negócios através de estudos e experimentos.')  \
# 0                                                1.0
#
#    ('P3_d_ ', 'i Desenvolver e manter modelos Machine Learning em produção.')  \
# 0                                                0.0
#
#    ('P3_d_ ', 'j Gerenciar a expectativa das áreas de negócio em relação as entregas das equipes de dados.')  \
# 0                                                0.0
#
#    ('P3_d_ ', 'k Garantir a manutenção dos projetos e modelos em produção, em meio ao crescimento da empresa.')  \
# 0                                                1.0
#
#    ('P3_d_l ', 'Conseguir levar inovação para a empresa através dos dados.')  \
# 0                                                0.0
#
#    ('P3_d_m ', 'Garantir retorno do investimento (ROI) em projetos de dados.')  \
# 0                                                1.0
#
#    ('P3_d_n ', 'Dividir o tempo entre entregas técnicas e gestão.')  \
# 0                                                0.0
#
#   ('P4_a_a ', 'Mesmo que esse não seja seu cargo formal, você considera que sua atuação no dia a dia, reflete alguma das opções listadas abaixo?')  \
# 0                                                NaN
#
#   ('P4_a ', 'Atuacao')  \
# 0               Gestor
#
#   ('P4_b ', 'Quais das fontes de dados listadas você já analisou ou processou no trabalho?')  \
# 0                                                NaN
#
#    ('P4_b_a ', 'Dados relacionais (estruturados em bancos SQL)')  \
# 0                                                NaN
#
#    ('P4_b_b ', 'Dados armazenados em bancos NoSQL')  ('P4_b_c ', 'Imagens')  \
# 0                                               NaN                     NaN
#
#    ('P4_b_d ', 'Textos/Documentos')  ('P4_b_e ', 'Vídeos')  \
# 0                               NaN                    NaN
#
#    ('P4_b_f ', 'Áudios')  ('P4_b_g ', 'Planilhas')  \
# 0                    NaN                       NaN
#
#    ('P4_b_h ', 'Dados georeferenciados')  \
# 0                                    NaN
#
#   ('P4_c ', 'Entre as fontes de dados listadas, quais você utiliza na maior parte do tempo?')  \
# 0                                                NaN
#
#    ('P4_c_a ', 'Dados relacionais (estruturados em bancos SQL)')  \
# 0                                                NaN
#
#    ('P4_c_b ', 'Dados armazenados em bancos NoSQL')  ('P4_c_c ', 'Imagens')  \
# 0                                               NaN                     NaN
#
#    ('P4_c_d ', 'Textos/Documentos')  ('P4_c_e ', 'Vídeos')  \
# 0                               NaN                    NaN
#
#    ('P4_c_f ', 'Áudios')  ('P4_c_g ', 'Planilhas')  \
# 0                    NaN                       NaN
#
#    ('P4_c_h ', 'Dados georeferenciados')  \
# 0                                    NaN
#
#   ('P4_d ', 'Quais das linguagens listadas abaixo você utiliza no trabalho?')  \
# 0                                                NaN
#
#    ('P4_d_a ', 'SQL')  ('P4_d_b ', 'R ')  ('P4_d_c ', 'Python')  \
# 0                 NaN                NaN                    NaN
#
#    ('P4_d_d ', 'C/C++/C#')  ('P4_d_e ', '.NET')  ('P4_d_f ', 'Java')  \
# 0                      NaN                  NaN                  NaN
#
#    ('P4_d_g ', 'Julia')  ('P4_d_h ', 'SAS/Stata')  \
# 0                   NaN                       NaN
#
#    ('P4_d_i ', 'Visual Basic/VBA')  ('P4_d_j ', 'Scala')  \
# 0                              NaN                   NaN
#
#    ('P4_d_k ', 'Matlab')  ('P4_d_l ', 'PHP')  ('P4_d_m ', 'Javascript')  \
# 0                    NaN                 NaN                        NaN
#
#    ('P4_d_n ', 'Não utilizo nenhuma linguagem')  \
# 0                                           NaN
#
#   ('P4_e ', 'Entre as linguagens listadas abaixo, qual é a que você mais utiliza no trabalho?')  \
# 0                                                NaN
#
#    ('P4_e_a ', 'SQL')  ('P4_e_b ', 'R ')  ('P4_e_c ', 'Python')  \
# 0                 NaN                NaN                    NaN
#
#    ('P4_e_d ', 'C/C++/C#')  ('P4_e_e ', '.NET')  ('P4_e_f ', 'Java')  \
# 0                      NaN                  NaN                  NaN
#
#    ('P4_e_g ', 'Julia')  ('P4_e_h ', 'SAS/Stata')  \
# 0                   NaN                       NaN
#
#    ('P4_e_i ', 'Visual Basic/VBA')  ('P4_e_j ', 'Scala')  \
# 0                              NaN                   NaN
#
#    ('P4_e_k ', 'Matlab')  ('P4_e_l ', 'PHP')  ('P4_e_m ', 'Javascript')  \
# 0                    NaN                 NaN                        NaN
#
#    ('P4_e_n ', 'Não utilizo nenhuma linguagem')  \
# 0                                           NaN
#
#   ('P4_f ', 'Quais dos bancos de dados/fontes de dados listados abaixo você utiliza no trabalho?')  \
# 0                                                NaN
#
#    ('P4_f_a ', 'MySQL')  ('P4_f_b ', 'Oracle')  ('P4_f_c ', 'SQL SERVER')  \
# 0                   NaN                    NaN                        NaN
#
#    ('P4_f_d ', 'SAP')  ('P4_f_e ', 'Amazon Aurora ou RDS')  \
# 0                 NaN                                  NaN
#
#    ('P4_f_f ', 'Amazon DynamoDB')  ('P4_f_g ', 'CoachDB')  \
# 0                             NaN                     NaN
#
#    ('P4_f_h ', 'Cassandra')  ('P4_f_i ', 'MongoDB')  ('P4_f_j ', 'MariaDB')  \
# 0                       NaN                     NaN                     NaN
#
#    ('P4_f_k ', 'Datomic')  ('P4_f_l ', 'S3')  ('P4_f_m ', 'PostgreSQL')  \
# 0                     NaN                NaN                        NaN
#
#    ('P4_f_n ', 'ElasticSearch')  ('P4_f_o ', 'DB2')  \
# 0                           NaN                 NaN
#
#    ('P4_f_p ', 'Microsoft Access')  ('P4_f_q ', 'SQLite')  \
# 0                              NaN                    NaN
#
#    ('P4_f_r ', 'Sybase')  ('P4_f_s ', 'Firebase')  ('P4_f_t ', 'Vertica')  \
# 0                    NaN                      NaN                     NaN
#
#    ('P4_f_u ', 'Redis')  ('P4_f_v ', 'Neo4J')  ('P4_f_x ', 'Google BigQuery')  \
# 0                   NaN                   NaN                             NaN
#
#    ('P4_f_y ', 'Google Firestore')  ('P4_f_z ', 'Amazon Redshift')  \
# 0                              NaN                             NaN
#
#    ('P4_f_z1 ', 'Amazon Athena')  ('P4_f_z2 ', 'Snowflake')  \
# 0                            NaN                        NaN
#
#    ('P4_f_z3 ', 'Databricks')  ('P4_f_z4 ', 'HBase')  ('P4_f_z5 ', 'Presto')  \
# 0                         NaN                    NaN                     NaN
#
#    ('P4_f_z6 ', 'Splunk')  ('P4_f_z7 ', 'SAP HANA')  ('P4_f_z8 ', 'Hive')  \
# 0                     NaN                       NaN                   NaN
#
#    ('P4_f_z9 ', 'Firebird')  \
# 0                       NaN
#
#   ('P4_g ', 'Quais das opções de Cloud listadas abaixo você utiliza no trabalho?')  \
# 0                                                NaN
#
#    ('P4_g_a ', 'Amazon Web Services (AWS)')  \
# 0                                       NaN
#
#    ('P4_g_b ', 'Google Cloud (GCP)')  ('P4_g_c ', 'Azure (Microsoft)')  \
# 0                                NaN                               NaN
#
#    ('P4_g_d ', 'Oracle Cloud')  ('P4_g_e ', 'IBM')  \
# 0                          NaN                 NaN
#
#    ('P4_g_f ', 'Servidores On Premise/Não utilizamos Cloud')  \
# 0                                                NaN
#
#    ('P4_g_g ', 'Cloud Própria')  \
# 0                           NaN
#
#   ('P4_h ', 'Quais as Ferramentas de Business Intelligence você utiliza no trabalho?')  \
# 0                                                NaN
#
#    ('P4_h_a ', 'Microsoft PowerBI')  ('P4_h_b ', 'Qlik View/Qlik Sense')  \
# 0                               NaN                                  NaN
#
#    ('P4_h_c ', 'Tableau')  ('P4_h_d ', 'Metabase')  ('P4_h_e ', 'Superset')  \
# 0                     NaN                      NaN                      NaN
#
#    ('P4_h_f ', 'Redash')  ('P4_h_g ', 'MicroStrategy')  \
# 0                    NaN                           NaN
#
#    ('P4_h_h ', 'IBM Analytics/Cognos')  ('P4_h_i ', 'SAP Business Objects')  \
# 0                                  NaN                                  NaN
#
#    ('P4_h_j ', 'Oracle Business Intelligence')  \
# 0                                          NaN
#
#    ('P4_h_k ', 'Amazon QuickSight')  \
# 0                               NaN
#
#    ('P4_h_l ', 'Salesforce/Einstein Analytics')  ('P4_h_m ', 'Mode')  \
# 0                                           NaN                  NaN
#
#    ('P4_h_n ', 'Alteryx')  ('P4_h_o ', 'Birst')  ('P4_h_p ', 'Looker')  \
# 0                     NaN                   NaN                    NaN
#
#    ('P4_h_q ', 'Google Data Studio')  ('P4_h_r ', 'SAS Visual Analytics')  \
# 0                                NaN                                  NaN
#
#    ('P4_h_s ', 'Grafana')  ('P4_h_t ', 'TIBCO Spotfire')  \
# 0                     NaN                            NaN
#
#    ('P4_h_u ', 'Pentaho')  \
# 0                     NaN
#
#    ('P4_h_v ', 'Fazemos todas as análises utilizando apenas Excel ou planilhas do google')  \
# 0                                                NaN
#
#    ('P4_h_x ', 'Não utilizo nenhuma ferramenta de BI no trabalho')  \
# 0                                                NaN
#
#   ('P5_b ', 'Qual oportunidade você está buscando?')  \
# 0                                                NaN
#
#   ('P5_c ', 'Há quanto tempo você busca uma oportunidade na área de dados?')  \
# 0                                                NaN
#
#   ('P5_d ', 'Como tem sido a busca por um emprego na área de dados?')  \
# 0                                                NaN
#
#   ('P6_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual como engenheiro de dados?')  \
# 0                                                NaN
#
#    ('P6_a_a ', 'Desenvolvo pipelines de dados utilizando linguagens de programação como Python, Scala, Java etc.')  \
# 0                                                NaN
#
#    ('P6_a_b ', 'Realizo construções de ETL's em ferramentas como Pentaho, Talend, Dataflow etc.')  \
# 0                                                NaN
#
#    ('P6_a_c ', 'Crio consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')  \
# 0                                                NaN
#
#    ('P6_a_d ', 'Atuo na integração de diferentes fontes de dados através de plataformas proprietárias como Stitch Data, Fivetran etc.')  \
# 0                                                NaN
#
#    ('P6_a_e ', 'Modelo soluções de arquitetura de dados, criando componentes de ingestão de dados, transformação e recuperação da informação.')  \
# 0                                                NaN
#
#    ('P6_a_f ', 'Desenvolvo/cuido da manutenção de repositórios de dados baseados em streaming de eventos como Data Lakes e Data Lakehouses.')  \
# 0                                                NaN
#
#    ('P6_a_g ', 'Atuo na modelagem dos dados, com o objetivo de criar conjuntos de dados como Data Warehouses, Data Marts etc.')  \
# 0                                                NaN
#
#    ('P6_a_h ', 'Cuido da qualidade dos dados, metadados e dicionário de dados.')  \
# 0                                                NaN
#
#    ('P6_a_i ', 'Nenhuma das opções listadas refletem meu dia a dia.')  \
# 0                                                NaN
#
#   ('P6_b ', 'Quais as ferramentas/tecnologias de ETL que você utiliza no trabalho como Data Engineer?')  \
# 0                                                NaN
#
#    ('P6_b_a ', 'Scripts Python')  ('P6_b_b ', 'SQL & Stored Procedures')  \
# 0                            NaN                                     NaN
#
#    ('P6_b_c ', 'Apache Airflow')  ('P6_b_d ', 'Luigi')  \
# 0                            NaN                   NaN
#
#    ('P6_b_e ', 'AWS Glue')  ('P6_b_f ', 'Talend')  ('P6_b_g ', 'Stitch')  \
# 0                      NaN                    NaN                    NaN
#
#    ('P6_b_h ', 'Fivetran')  ('P6_b_i ', 'Google Dataflow')  \
# 0                      NaN                             NaN
#
#    ('P6_b_j ', 'Oracle Data Integrator')  ('P6_b_k ', 'IBM DataStage')  \
# 0                                    NaN                           NaN
#
#    ('P6_b_l ', 'SAP BW ETL')  \
# 0                        NaN
#
#    ('P6_b_m ', 'SQL Server Integration Services (SSIS)')  \
# 0                                                NaN
#
#    ('P6_b_n ', 'SAS Data Integration')  ('P6_b_o ', 'Qlik Sense')  \
# 0                                  NaN                        NaN
#
#    ('P6_b_p ', 'Knime')  ('P6_b_q ', 'Não utilizo ferramentas de ETL')  \
# 0                   NaN                                            NaN
#
#    ('P6_c ', 'Sua organização possui um Data Lake?')  \
# 0                                                NaN
#
#   ('P6_d ', 'Qual tecnologia utilizada como plataforma do Data Lake?')  \
# 0                                                NaN
#
#    ('P6_e ', 'Sua organização possui um Data Warehouse?')  \
# 0                                                NaN
#
#   ('P6_f ', 'Qual tecnologia utilizada como plataforma do Data Warehouse?')  \
# 0                                                NaN
#
#   ('P6_g ', 'Quais as ferramentas de gestão de Qualidade de dados, Metadados e catálogo de dados você utiliza no trabalho?')  \
# 0                                                NaN
#
#    ('P6_g_a ', 'great_expectations')  ('P6_g_b ', 'dbt')  \
# 0                                NaN                 NaN
#
#    ('P6_g_c ', 'AWS Deequ')  ('P6_g_d ', 'Apache Griffin')  \
# 0                       NaN                            NaN
#
#    ('P6_g_e ', 'Datafold')  ('P6_g_f ', 'Amundsen')  \
# 0                      NaN                      NaN
#
#    ('P6_g_g ', 'Monte Carlo')  ('P6_g_h ', 'SODA')  ('P6_g_i ', 'Big Eye')  \
# 0                         NaN                  NaN                     NaN
#
#    ('P6_g_j ', 'Data Band')  ('P6_g_k ', 'Anomalo')  ('P6_g_l ', 'Metaplane')  \
# 0                       NaN                     NaN                       NaN
#
#    ('P6_g_m ', 'Acceldata')  \
# 0                       NaN
#
#   ('P6_h ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo?')  \
# 0                                                NaN
#
#    ('P6_h_a ', 'Desenvolvendo pipelines de dados utilizando linguagens de programação como Python, Scala, Java etc.')  \
# 0                                                NaN
#
#    ('P6_h_b ', 'Realizando construções de ETL's em ferramentas como Pentaho, Talend, Dataflow etc.')  \
# 0                                                NaN
#
#    ('P6_h_c ', 'Criando consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')  \
# 0                                                NaN
#
#    ('P6_h_d ', 'Atuando na integração de diferentes fontes de dados através de plataformas proprietárias como Stitch Data, Fivetran etc.')  \
# 0                                                NaN
#
#    ('P6_h_e ', 'Modelando soluções de arquitetura de dados, criando componentes de ingestão de dados, transformação e recuperação da informação.')  \
# 0                                                NaN
#
#    ('P6_h_f ', 'Desenvolvendo/cuidando da manutenção de repositórios de dados baseados em streaming de eventos como Data Lakes e Data Lakehouses.')  \
# 0                                                NaN
#
#    ('P6_h_g ', 'Atuando na modelagem dos dados, com o objetivo de criar conjuntos de dados como Data Warehouses, Data Marts etc.')  \
# 0                                                NaN
#
#    ('P6_h_h ', 'Cuidando da qualidade dos dados, metadados e dicionário de dados.')  \
# 0                                                NaN
#
#   ('P7_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual com análise de dados?')  \
# 0                                                NaN
#
#    ('P7_a_a ', 'Processo e analiso dados utilizando linguagens de programação como Python, R etc.')  \
# 0                                                NaN
#
#    ('P7_a_b ', 'Realizo construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik etc.')  \
# 0                                                NaN
#
#    ('P7_a_c ', 'Utilizo API's para extrair dados e complementar minhas análises.')  \
# 0                                                NaN
#
#    ('P7_a_d ', 'Realizo experimentos e estudos utilizando metodologias estatísticas como teste de hipótese, modelos de regressão etc.')  \
# 0                                                NaN
#
#    ('P7_a_e ', 'Desenvolvo/cuido da manutenção de ETL's utilizando tecnologias como Talend, Pentaho, Airflow, Dataflow etc.')  \
# 0                                                NaN
#
#    ('P7_a_f ', 'Atuo na modelagem dos dados, com o objetivo de criar conjuntos de dados, Data Warehouses, Data Marts etc.')  \
# 0                                                NaN
#
#    ('P7_a_g ', 'Desenvolvo/cuido da manutenção de planilhas para atender as áreas de negócio.')  \
# 0                                                NaN
#
#    ('P7_a_h ', 'Utilizo ferramentas avançadas de estatística como SAS')  \
# 0                                                NaN
#
#   ('P7_b ', 'Quais as ferramentas/tecnologias de ETL que você utiliza no trabalho como Data Analyst?')  \
# 0                                                NaN
#
#    ('P7_b_a ', 'Scripts Python')  ('P7_b_b ', 'SQL & Stored Procedures')  \
# 0                            NaN                                     NaN
#
#    ('P7_b_c ', 'Apache Airflow')  ('P7_b_d ', 'Luigi')  \
# 0                            NaN                   NaN
#
#    ('P7_b_e ', 'AWS Glue')  ('P7_b_f ', 'Talend')  ('P7_b_g ', 'Stitch')  \
# 0                      NaN                    NaN                    NaN
#
#    ('P7_b_h ', 'Fivetran')  ('P7_b_i ', 'Google Dataflow')  \
# 0                      NaN                             NaN
#
#    ('P7_b_j ', 'Oracle Data Integrator')  ('P7_b_k ', 'IBM DataStage')  \
# 0                                    NaN                           NaN
#
#    ('P7_b_l ', 'SAP BW ETL')  \
# 0                        NaN
#
#    ('P7_b_m ', 'SQL Server Integration Services (SSIS)')  \
# 0                                                NaN
#
#    ('P7_b_n ', 'SAS Data Integration')  ('P7_b_o ', 'Qlik Sense')  \
# 0                                  NaN                        NaN
#
#    ('P7_b_p ', 'Knime')  ('P7_b_q ', 'Não utilizo ferramentas de ETL')  \
# 0                   NaN                                            NaN
#
#   ('P7_c ', 'Sua empresa utiliza alguma das ferramentas listadas para dar mais autonomia em análise de dados para as áreas de negócio?')  \
# 0                                                NaN
#
#    ('P7_c_a ', 'Ferramentas de AutoML como H2O.ai, Data Robot, BigML etc.')  \
# 0                                                NaN
#
#    ('P7_c_b ', '""Point and Click"" Analytics como Alteryx, Knime, Rapidminer etc.')  \
# 0                                                NaN
#
#    ('P7_c_c ', 'Product metricts & Insights como Mixpanel, Amplitude, Adobe Analytics.')  \
# 0                                                NaN
#
#    ('P7_c_d ', 'Ferramentas de análise dentro de ferramentas de CRM como Salesforce Einstein Anaytics ou Zendesk dashboards.')  \
# 0                                                NaN
#
#    ('P7_c_e ', 'Minha empresa não utiliza essas ferramentas.')  \
# 0                                                NaN
#
#    ('P7_c_f ', 'Não sei informar.')  \
# 0                               NaN
#
#   ('P7_d ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo de trabalho?')  \
# 0                                                NaN
#
#    ('P7_d_a ', 'Processando e analisando dados utilizando linguagens de programação como Python, R etc.')  \
# 0                                                NaN
#
#    ('P7_d_b ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik etc.')  \
# 0                                                NaN
#
#    ('P7_d_c ', 'Utilizando API's para extrair dados e complementar minhas análises.')  \
# 0                                                NaN
#
#    ('P7_d_d ', 'Realizando experimentos e estudos utilizando metodologias estatísticas como teste de hipótese, modelos de regressão etc.')  \
# 0                                                NaN
#
#    ('P7_d_e ', 'Desenvolvendo/cuidando da manutenção de ETL's utilizando tecnologias como Talend, Pentaho, Airflow, Dataflow etc.')  \
# 0                                                NaN
#
#    ('P7_d_f ', 'Atuando na modelagem dos dados, com o objetivo de criar conjuntos de dados, Data Warehouses, Data Marts etc.')  \
# 0                                                NaN
#
#    ('P7_d_g ', 'Desenvolvendo/cuidando da manutenção de planilhas do Excel ou Google Sheets para atender as áreas de negócio.')  \
# 0                                                NaN
#
#    ('P7_d_h ', 'Utilizando ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises.')  \
# 0                                                NaN
#
#   ('P8_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual com ciência de dados?')  \
# 0                                                NaN
#
#    ('P8_a_a ', 'Estudos Ad-hoc com o objetivo de confirmar hipóteses, realizar modelos preditivos, forecasts, análise de cluster para resolver problemas pontuais e responder perguntas das áreas de negócio.')  \
# 0                                                NaN
#
#    ('P8_a_b ', 'Sou responsável pela coleta e limpeza dos dados que uso para análise e modelagem.')  \
# 0                                                NaN
#
#    ('P8_a_c ', 'Sou responsável por entrar em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')  \
# 0                                                NaN
#
#    ('P8_a_d ', 'Desenvolvo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')  \
# 0                                                NaN
#
#    ('P8_a_e ', 'Sou responsável por colocar modelos em produção, criar os pipelines de dados, APIs de consumo e monitoramento.')  \
# 0                                                NaN
#
#    ('P8_a_f ', 'Cuido da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.')  \
# 0                                                NaN
#
#    ('P8_a_g ', 'Realizo construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc')  \
# 0                                                NaN
#
#    ('P8_a_h ', 'Utilizo ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises estatísticas e ajustar modelos.Crio e dou manutenção em ETLs, DAGs e automações de pipelines de dados.')  \
# 0                                                NaN
#
#    ('P8_a_j ', 'Sou responsável por criar e manter a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')  \
# 0                                                NaN
#
#   ('P8_b ', 'Quais as técnicas e métodos listados abaixo você costuma utilizar no trabalho?')  \
# 0                                                NaN
#
#    ('P8_b_a ', 'Utilizo modelos de regressão (linear, logística, GLM)')  \
# 0                                                NaN
#
#    ('P8_b_b ', 'Utilizo redes neurais ou modelos baseados em árvore para criar modelos de classificação')  \
# 0                                                NaN
#
#    ('P8_b_c ', 'Desenvolvo sistemas de recomendação (RecSys)')  \
# 0                                                NaN
#
#    ('P8_b_d ', 'Utilizo métodos estatísticos Bayesianos para analisar dados')  \
# 0                                                NaN
#
#    ('P8_b_e ', 'Utilizo técnicas de NLP (Natural Language Processing) para análisar dados não-estruturados')  \
# 0                                                NaN
#
#    ('P8_b_f ', 'Utilizo métodos estatísticos clássicos (Testes de hipótese, análise multivariada, sobrevivência, dados longitudinais, inferência estatistica) para analisar dados')  \
# 0                                                NaN
#
#    ('P8_b_g ', 'Utilizo cadeias de Markov ou HMM's para realizar análises de dados')  \
# 0                                                NaN
#
#    ('P8_b_h ', 'Desenvolvo técnicas de Clusterização (K-means, Spectral, DBScan etc)')  \
# 0                                                NaN
#
#    ('P8_b_i ', 'Realizo previsões através de modelos de Séries Temporais (Time Series)')  \
# 0                                                NaN
#
#    ('P8_b_j ', 'Utilizo modelos de Reinforcement Learning (aprendizado por reforço)')  \
# 0                                                NaN
#
#    ('P8_b_k ', 'Utilizo modelos de Machine Learning para detecção de fraude')  \
# 0                                                NaN
#
#    ('P8_b_l ', 'Utilizo métodos de Visão Computacional')  \
# 0                                                NaN
#
#    ('P8_b_m ', 'Utilizo modelos de Detecção de Churn')  \
# 0                                                NaN
#
#   ('P8_c ', 'Quais dessas tecnologias fazem parte do seu dia a dia como cientista de dados?')  \
# 0                                                NaN
#
#    ('P8_c_a ', 'Ferramentas de BI (PowerBI, Looker, Tableau, Qlik etc)')  \
# 0                                                NaN
#
#    ('P8_c_b ', 'Planilhas (Excel, Google Sheets etc)')  \
# 0                                                NaN
#
#    ('P8_c_c ', 'Ambientes de desenvolvimento local (R-studio, JupyterLab, Anaconda)')  \
# 0                                                NaN
#
#    ('P8_c_d ', 'Ambientes de desenvolvimento na nuvem (Google Colab, AWS Sagemaker, Kaggle Notebooks etc)')  \
# 0                                                NaN
#
#    ('P8_c_e ', 'Ferramentas de AutoML (Datarobot, H2O, Auto-Keras etc)')  \
# 0                                                NaN
#
#    ('P8_c_f ', 'Ferramentas de ETL (Apache Airflow, NiFi, Stitch, Fivetran, Pentaho etc)')  \
# 0                                                NaN
#
#    ('P8_c_g ', 'Plataformas de Machine Learning (TensorFlow, Azure Machine Learning, Kubeflow etc)')  \
# 0                                                NaN
#
#    ('P8_c_h ', 'Feature Store (Feast, Hopsworks, AWS Feature Store, Databricks Feature Store etc)')  \
# 0                                                NaN
#
#    ('P8_c_i ', 'Sistemas de controle de versão (Github, DVC, Neptune, Gitlab etc)')  \
# 0                                                NaN
#
#    ('P8_c_j ', 'Plataformas de Data Apps (Streamlit, Shiny, Plotly Dash etc)')  \
# 0                                                NaN
#
#    ('P8_c_k ', 'Ferramentas de estatística avançada como SPSS, SAS, etc.')  \
# 0                                                NaN
#
#    ('P8_c_l ', 'Não utilizo nenhuma dessas ferramentas no meu dia a dia.')  \
# 0                                                NaN
#
#   ('P8_d ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo no trabalho?')  \
# 0                                                NaN
#
#    ('P8_d_a ', 'Coletando e limpando os dados que uso para análise e modelagem.')  \
# 0                                                NaN
#
#    ('P8_d_b ', 'Entrando em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')  \
# 0                                                NaN
#
#    ('P8_d_c ', 'Desenvolvendo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')  \
# 0                                                NaN
#
#    ('P8_d_d ', 'Colocando modelos em produção, criando os pipelines de dados, APIs de consumo e monitoramento.')  \
# 0                                                NaN
#
#    ('P8_d_e ', 'Cuidando da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.')  \
# 0                                                NaN
#
#    ('P8_d_f ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc.')  \
# 0                                                NaN
#
#    ('P8_d_g ', 'Criando e dando manutenção em ETLs, DAGs e automações de pipelines de dados.')  \
# 0                                                NaN
#
#    ('P8_d_h ', 'Criando e gerenciando soluções de Feature Store e cultura de MLOps.')  \
# 0                                                NaN
#
#    ('P8_d_i ', 'Criando e mantendo a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')  \
# 0                                                NaN
#
#   ('P9_a ', 'Quais das iniciativas do Data Hackers que você já acessou/acompanhou?')  \
# 0        Newsletter Semanal, Podcast do Data Hackers
#
#    ('P9_a_a ', 'Blog/Medium do Data Hackers')  \
# 0                                           0
#
#    ('P9_a_b ', 'Podcast do Data Hackers')  ('P9_a_d ', 'Newsletter Semanal')  \
# 0                                       1                                  1
#
#    ('P9_a_e ', 'Canal do Slack')  \
# 0                              0
#
#    ('P9_a_f ', 'Canal do Youtube do Data Hackers')  \
# 0                                                0
#
#    ('P9_a_g ', 'Ainda não conhecia o Data Hackers')
# 0                                                 0

# %%
df.tail()
# Out:
#                           ('P0', 'id')  ('P1_a ', 'Idade')  \
# 2640  07nvo8cdy377a46gon207nvjebwe65zg                40.0
# 2641  01mqnby32u01pg3nuj6vipp4mc06s8pg                27.0
# 2642  01fncs8qbhl9zx01fncs8rqib2zl3d18                24.0
# 2643  075h3v2z19if04yn7o075h3vhifl38rw                38.0
# 2644  037usz1h2yip96dgil4mhj037uszw1gk                27.0
#
#      ('P1_a_a ', 'Faixa idade') ('P1_b ', 'Genero')  \
# 2640                      40-44           Masculino
# 2641                      25-29           Masculino
# 2642                      22-24           Masculino
# 2643                      35-39           Masculino
# 2644                      25-29            Feminino
#
#      ('P1_e ', 'Estado onde mora') ('P1_e_a ', 'uf onde mora')  \
# 2640                São Paulo (SP)                          SP
# 2641           Santa Catarina (SC)                          SC
# 2642           Santa Catarina (SC)                          SC
# 2643           Rio de Janeiro (RJ)                          RJ
# 2644             Minas Gerais (MG)                          MG
#
#      ('P1_e_b ', 'Regiao onde mora') ('P1_g_b ', 'Regiao de origem')  \
# 2640                         Sudeste                         Sudeste
# 2641                             Sul                             Sul
# 2642                             Sul                             NaN
# 2643                         Sudeste                             NaN
# 2644                         Sudeste                             NaN
#
#       ('P1_g_c ', 'Mudou de Estado?') ('P1_h ', 'Nivel de Ensino')  \
# 2640                                1   Não tenho graduação formal
# 2641                                1        Graduação/Bacharelado
# 2642                                0        Graduação/Bacharelado
# 2643                                0        Graduação/Bacharelado
# 2644                                0                Pós-graduação
#
#                           ('P1_i ', 'Área de Formação')  \
# 2640                                                NaN
# 2641  Estatística/ Matemática / Matemática Computaci...
# 2642  Computação / Engenharia de Software / Sistemas...
# 2643  Computação / Engenharia de Software / Sistemas...
# 2644                                             Outras
#
#      ('P2_a ', 'Qual sua situação atual de trabalho?')  \
# 2640            Trabalho na área Acadêmica/Pesquisador
# 2641                                   Empregado (CLT)
# 2642                                   Empregado (CLT)
# 2643                Desempregado, buscando recolocação
# 2644                Desempregado, buscando recolocação
#
#                   ('P2_b ', 'Setor') ('P2_c ', 'Numero de Funcionarios')  \
# 2640                             NaN                                 NaN
# 2641  Tecnologia/Fábrica de Software                       de 501 a 1000
# 2642  Tecnologia/Fábrica de Software                       Acima de 3000
# 2643                             NaN                                 NaN
# 2644                             NaN                                 NaN
#
#       ('P2_d ', 'Gestor?') ('P2_e ', 'Cargo como Gestor')  \
# 2640                   NaN                            NaN
# 2641                   0.0                            NaN
# 2642                   0.0                            NaN
# 2643                   NaN                            NaN
# 2644                   NaN                            NaN
#
#                ('P2_f ', 'Cargo Atual') ('P2_g ', 'Nivel')  \
# 2640                                NaN                NaN
# 2641  Cientista de Dados/Data Scientist              Pleno
# 2642  Engenheiro de Dados/Data Engineer              Pleno
# 2643                                NaN                NaN
# 2644                                NaN                NaN
#
#          ('P2_h ', 'Faixa salarial')  \
# 2640                             NaN
# 2641  de R$ 6.001/mês a R$ 8.000/mês
# 2642  de R$ 6.001/mês a R$ 8.000/mês
# 2643                             NaN
# 2644                             NaN
#
#      ('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')  \
# 2640                                                NaN
# 2641                                      de 4 a 5 anos
# 2642                                      de 2 a 3 anos
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')  \
# 2640                                                NaN
# 2641                                     Menos de 1 ano
# 2642                                      de 2 a 3 anos
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_k ', 'Você está satisfeito na sua empresa atual?')  \
# 2640                                                NaN
# 2641                                                1.0
# 2642                                                0.0
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P2_l ', 'Qual o principal motivo da sua insatisfação com a empresa atual?')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642  Salário atual não corresponde ao mercado, Gost...
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_l_a ', 'Falta de oportunidade de crescimento no emprego atual')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                0.0
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_l_b ', 'Salário atual não corresponde ao mercado')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                1.0
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_l_c ', 'Não tenho uma boa relação com meu líder/gestor')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                0.0
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_l_d ', 'Gostaria de trabalhar em em outra área de atuação')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                0.0
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_l_e ', 'Gostaria de receber mais benefícios')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                1.0
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_l_f ', 'O clima de trabalho/ambiente não é bom')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                0.0
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_l_g ', 'Falta de maturidade analítica na empresa')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                0.0
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P2_m ', 'Você participou de entrevistas de emprego nos últimos 6 meses?')  \
# 2640                                                NaN
# 2641               Sim, fui aprovado e mudei de emprego
# 2642               Sim, fui aprovado e mudei de emprego
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P2_n ', 'Você pretende mudar de emprego nos próximos 6 meses?')  \
# 2640                                                NaN
# 2641  Não estou buscando e não pretendo mudar de emp...
# 2642  Estou em busca de oportunidades dentro ou fora...
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P2_o ', 'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?')  \
# 2640                                                NaN
# 2641  Oportunidade de aprendizado e trabalhar com re...
# 2642  Remuneração/Salário, Benefícios, Propósito do ...
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_o_a ', 'Remuneração/Salário')  ('P2_o_b ', 'Benefícios')  \
# 2640                                 NaN                        NaN
# 2641                                 0.0                        0.0
# 2642                                 1.0                        1.0
# 2643                                 NaN                        NaN
# 2644                                 NaN                        NaN
#
#       ('P2_o_c ', 'Propósito do trabalho e da empresa')  \
# 2640                                                NaN
# 2641                                                0.0
# 2642                                                1.0
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_o_d ', 'Flexibilidade de trabalho remoto')  \
# 2640                                              NaN
# 2641                                              0.0
# 2642                                              0.0
# 2643                                              NaN
# 2644                                              NaN
#
#       ('P2_o_e ', 'Ambiente e clima de trabalho')  \
# 2640                                          NaN
# 2641                                          0.0
# 2642                                          0.0
# 2643                                          NaN
# 2644                                          NaN
#
#       ('P2_o_f ', 'Oportunidade de aprendizado e trabalhar com referências na área')  \
# 2640                                                NaN
# 2641                                                1.0
# 2642                                                0.0
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_o_g ', 'Plano de carreira e oportunidades de crescimento profissional')  \
# 2640                                                NaN
# 2641                                                1.0
# 2642                                                0.0
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_o_h ', 'Maturidade da empresa em termos de tecnologia e dados')  \
# 2640                                                NaN
# 2641                                                0.0
# 2642                                                0.0
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_o_i ', 'Qualidade dos gestores e líderes')  \
# 2640                                              NaN
# 2641                                              1.0
# 2642                                              0.0
# 2643                                              NaN
# 2644                                              NaN
#
#       ('P2_o_j ', 'Reputação que a empresa tem no mercado')  \
# 2640                                                NaN
# 2641                                                0.0
# 2642                                                0.0
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P2_q ', 'Atualmente qual a sua forma de trabalho?')  \
# 2640                                                NaN
# 2641                             Modelo 100% presencial
# 2642                                 Modelo 100% remoto
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P2_r ', 'Qual a forma de trabalho ideal para você?')  \
# 2640                                                NaN
# 2641                             Modelo 100% presencial
# 2642                                 Modelo 100% remoto
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P2_s ', 'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?')  \
# 2640                                                NaN
# 2641  Vou aceitar e retornar ao modelo 100% presencial.
# 2642  Vou procurar outra oportunidade no modelo 100%...
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P3_a ', 'Qual o número aproximado de pessoas que atuam com dados na sua empresa hoje?')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P3_b ', 'Quais desses papéis/cargos fazem parte do time (ou chapter) de dados da sua empresa?')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_b_a ', 'Analytics Engineer')  \
# 2640                                NaN
# 2641                                NaN
# 2642                                NaN
# 2643                                NaN
# 2644                                NaN
#
#       ('P3_b_b ', 'Engenharia de Dados/Data Engineer')  \
# 2640                                               NaN
# 2641                                               NaN
# 2642                                               NaN
# 2643                                               NaN
# 2644                                               NaN
#
#       ('P3_b_c ', 'Analista de Dados/Data Analyst')  \
# 2640                                            NaN
# 2641                                            NaN
# 2642                                            NaN
# 2643                                            NaN
# 2644                                            NaN
#
#       ('P3_b_d ', 'Cientista de Dados/Data Scientist')  \
# 2640                                               NaN
# 2641                                               NaN
# 2642                                               NaN
# 2643                                               NaN
# 2644                                               NaN
#
#       ('P3_b_e ', 'Database Administrator/DBA')  \
# 2640                                        NaN
# 2641                                        NaN
# 2642                                        NaN
# 2643                                        NaN
# 2644                                        NaN
#
#       ('P3_b_f ', 'Analista de Business Intelligence/BI')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_b_g ', 'Arquiteto de Dados/Data Architect')  \
# 2640                                               NaN
# 2641                                               NaN
# 2642                                               NaN
# 2643                                               NaN
# 2644                                               NaN
#
#       ('P3_b_h ', 'Data Product Manager/DPM')  \
# 2640                                      NaN
# 2641                                      NaN
# 2642                                      NaN
# 2643                                      NaN
# 2644                                      NaN
#
#       ('P3_b_i ', 'Business Analyst')  \
# 2640                              NaN
# 2641                              NaN
# 2642                              NaN
# 2643                              NaN
# 2644                              NaN
#
#      ('P3_c ', 'Quais dessas responsabilidades fazem parte da sua rotina atual de trabalho como gestor?')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_c_a ', 'Pensar na visão de longo prazo de dados da empresa e fortalecimento da cultura analítica da companhia.')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_c_b ', 'Organização de treinamentos e iniciativas com o objetivo de aumentar a maturidade analítica das áreas de negócios.')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_c_c ', 'Atração, seleção e contratação de talentos para o time de dados.')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_c_d ', 'Decisão sobre contratação de ferramentas e tecnologias relacionadas a dados.')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_c_e ', 'Sou gestor da equipe responsável pela engenharia de dados e por manter o Data Lake da empresa como fonte única dos dados, garantindo a qualidade e confiabilidade da informação.')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_c_f ', 'Sou gestor da equipe responsável pela entrega de dados, estudos, relatórios e dashboards para as áreas de negócio da empresa.')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_c_g ', 'Sou gestor da equipe responsável por iniciativas e projetos envolvendo Inteligência Artificial e Machine Learning.')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_c_h ', 'Apesar de ser gestor ainda atuo na parte técnica, construindo soluções/análises/modelos etc.')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_c_i ', 'Gestão de projetos de dados, cuidando das etapas, equipes envolvidas, atingimento dos objetivos etc.')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_c_j ', 'Gestão de produtos de dados, cuidando da visão dos produtos, backlog, feedback de usuários etc.')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_c_k ', 'Gestão de pessoas, apoio no desenvolvimento das pessoas, evolução de carreira')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P3_d ', 'Quais são os 3 maiores desafios que você tem como gestor no atual momento?')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_d_ ', 'a Contratar novos talentos.')  \
# 2640                                        NaN
# 2641                                        NaN
# 2642                                        NaN
# 2643                                        NaN
# 2644                                        NaN
#
#       ('P3_d_ ', 'b Reter talentos.')  \
# 2640                              NaN
# 2641                              NaN
# 2642                              NaN
# 2643                              NaN
# 2644                              NaN
#
#       ('P3_d_ ', 'c Convencer a empresa a aumentar os investimentos na área de dados.')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_d_ ', 'd Gestão de equipes no ambiente remoto.')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_d_ ', 'e Gestão de projetos envolvendo áreas multidisciplinares da empresa.')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_d_ ', 'f Organizar as informações e garantir a qualidade e confiabilidade.')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_d_ ', 'g Conseguir processar e armazenar um alto volume de dados.')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_d_ ', 'h Conseguir gerar valor para as áreas de negócios através de estudos e experimentos.')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_d_ ', 'i Desenvolver e manter modelos Machine Learning em produção.')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_d_ ', 'j Gerenciar a expectativa das áreas de negócio em relação as entregas das equipes de dados.')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_d_ ', 'k Garantir a manutenção dos projetos e modelos em produção, em meio ao crescimento da empresa.')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_d_l ', 'Conseguir levar inovação para a empresa através dos dados.')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_d_m ', 'Garantir retorno do investimento (ROI) em projetos de dados.')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_d_n ', 'Dividir o tempo entre entregas técnicas e gestão.')  \
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P4_a_a ', 'Mesmo que esse não seja seu cargo formal, você considera que sua atuação no dia a dia, reflete alguma das opções listadas abaixo?')  \
# 2640                                                NaN
# 2641  *Ciência de Dados/Machine Learning: *Desenha e...
# 2642  *Engenharia de Dados:* Modela soluções de arqu...
# 2643                                                NaN
# 2644                                                NaN
#
#                     ('P4_a ', 'Atuacao')  \
# 2640  Buscando emprego na área de dados.
# 2641                    Ciência de Dados
# 2642                 Engenharia de Dados
# 2643  Buscando emprego na área de dados.
# 2644  Buscando emprego na área de dados.
#
#      ('P4_b ', 'Quais das fontes de dados listadas você já analisou ou processou no trabalho?')  \
# 2640                                                NaN
# 2641  Dados relacionais (estruturados em bancos SQL)...
# 2642  Dados relacionais (estruturados em bancos SQL)...
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P4_b_a ', 'Dados relacionais (estruturados em bancos SQL)')  \
# 2640                                                NaN
# 2641                                                1.0
# 2642                                                1.0
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P4_b_b ', 'Dados armazenados em bancos NoSQL')  \
# 2640                                               NaN
# 2641                                               1.0
# 2642                                               0.0
# 2643                                               NaN
# 2644                                               NaN
#
#       ('P4_b_c ', 'Imagens')  ('P4_b_d ', 'Textos/Documentos')  \
# 2640                     NaN                               NaN
# 2641                     0.0                               1.0
# 2642                     0.0                               0.0
# 2643                     NaN                               NaN
# 2644                     NaN                               NaN
#
#       ('P4_b_e ', 'Vídeos')  ('P4_b_f ', 'Áudios')  ('P4_b_g ', 'Planilhas')  \
# 2640                    NaN                    NaN                       NaN
# 2641                    0.0                    0.0                       1.0
# 2642                    0.0                    0.0                       1.0
# 2643                    NaN                    NaN                       NaN
# 2644                    NaN                    NaN                       NaN
#
#       ('P4_b_h ', 'Dados georeferenciados')  \
# 2640                                    NaN
# 2641                                    1.0
# 2642                                    0.0
# 2643                                    NaN
# 2644                                    NaN
#
#      ('P4_c ', 'Entre as fontes de dados listadas, quais você utiliza na maior parte do tempo?')  \
# 2640                                                NaN
# 2641  Dados relacionais (estruturados em bancos SQL)...
# 2642  Dados relacionais (estruturados em bancos SQL)...
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P4_c_a ', 'Dados relacionais (estruturados em bancos SQL)')  \
# 2640                                                NaN
# 2641                                                1.0
# 2642                                                1.0
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P4_c_b ', 'Dados armazenados em bancos NoSQL')  \
# 2640                                               NaN
# 2641                                               1.0
# 2642                                               0.0
# 2643                                               NaN
# 2644                                               NaN
#
#       ('P4_c_c ', 'Imagens')  ('P4_c_d ', 'Textos/Documentos')  \
# 2640                     NaN                               NaN
# 2641                     0.0                               0.0
# 2642                     0.0                               0.0
# 2643                     NaN                               NaN
# 2644                     NaN                               NaN
#
#       ('P4_c_e ', 'Vídeos')  ('P4_c_f ', 'Áudios')  ('P4_c_g ', 'Planilhas')  \
# 2640                    NaN                    NaN                       NaN
# 2641                    0.0                    0.0                       0.0
# 2642                    0.0                    0.0                       1.0
# 2643                    NaN                    NaN                       NaN
# 2644                    NaN                    NaN                       NaN
#
#       ('P4_c_h ', 'Dados georeferenciados')  \
# 2640                                    NaN
# 2641                                    0.0
# 2642                                    0.0
# 2643                                    NaN
# 2644                                    NaN
#
#      ('P4_d ', 'Quais das linguagens listadas abaixo você utiliza no trabalho?')  \
# 2640                                                NaN
# 2641                                     SQL, R, Python
# 2642                                        SQL, Python
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P4_d_a ', 'SQL')  ('P4_d_b ', 'R ')  ('P4_d_c ', 'Python')  \
# 2640                 NaN                NaN                    NaN
# 2641                 1.0                1.0                    1.0
# 2642                 1.0                0.0                    1.0
# 2643                 NaN                NaN                    NaN
# 2644                 NaN                NaN                    NaN
#
#       ('P4_d_d ', 'C/C++/C#')  ('P4_d_e ', '.NET')  ('P4_d_f ', 'Java')  \
# 2640                      NaN                  NaN                  NaN
# 2641                      0.0                  0.0                  0.0
# 2642                      0.0                  0.0                  0.0
# 2643                      NaN                  NaN                  NaN
# 2644                      NaN                  NaN                  NaN
#
#       ('P4_d_g ', 'Julia')  ('P4_d_h ', 'SAS/Stata')  \
# 2640                   NaN                       NaN
# 2641                   0.0                       0.0
# 2642                   0.0                       0.0
# 2643                   NaN                       NaN
# 2644                   NaN                       NaN
#
#       ('P4_d_i ', 'Visual Basic/VBA')  ('P4_d_j ', 'Scala')  \
# 2640                              NaN                   NaN
# 2641                              0.0                   0.0
# 2642                              0.0                   0.0
# 2643                              NaN                   NaN
# 2644                              NaN                   NaN
#
#       ('P4_d_k ', 'Matlab')  ('P4_d_l ', 'PHP')  ('P4_d_m ', 'Javascript')  \
# 2640                    NaN                 NaN                        NaN
# 2641                    0.0                 0.0                        0.0
# 2642                    0.0                 0.0                        0.0
# 2643                    NaN                 NaN                        NaN
# 2644                    NaN                 NaN                        NaN
#
#       ('P4_d_n ', 'Não utilizo nenhuma linguagem')  \
# 2640                                           NaN
# 2641                                           0.0
# 2642                                           0.0
# 2643                                           NaN
# 2644                                           NaN
#
#      ('P4_e ', 'Entre as linguagens listadas abaixo, qual é a que você mais utiliza no trabalho?')  \
# 2640                                                NaN
# 2641                                             Python
# 2642                                                SQL
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P4_e_a ', 'SQL')  ('P4_e_b ', 'R ')  ('P4_e_c ', 'Python')  \
# 2640                 NaN                NaN                    NaN
# 2641                 0.0                0.0                    1.0
# 2642                 1.0                0.0                    0.0
# 2643                 NaN                NaN                    NaN
# 2644                 NaN                NaN                    NaN
#
#       ('P4_e_d ', 'C/C++/C#')  ('P4_e_e ', '.NET')  ('P4_e_f ', 'Java')  \
# 2640                      NaN                  NaN                  NaN
# 2641                      0.0                  0.0                  0.0
# 2642                      0.0                  0.0                  0.0
# 2643                      NaN                  NaN                  NaN
# 2644                      NaN                  NaN                  NaN
#
#       ('P4_e_g ', 'Julia')  ('P4_e_h ', 'SAS/Stata')  \
# 2640                   NaN                       NaN
# 2641                   0.0                       0.0
# 2642                   0.0                       0.0
# 2643                   NaN                       NaN
# 2644                   NaN                       NaN
#
#       ('P4_e_i ', 'Visual Basic/VBA')  ('P4_e_j ', 'Scala')  \
# 2640                              NaN                   NaN
# 2641                              0.0                   0.0
# 2642                              0.0                   0.0
# ...
#
#       ('P8_c_a ', 'Ferramentas de BI (PowerBI, Looker, Tableau, Qlik etc)')  \
# 2640                                                NaN
# 2641                                                0.0
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_c_b ', 'Planilhas (Excel, Google Sheets etc)')  \
# 2640                                                NaN
# 2641                                                0.0
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_c_c ', 'Ambientes de desenvolvimento local (R-studio, JupyterLab, Anaconda)')  \
# 2640                                                NaN
# 2641                                                0.0
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_c_d ', 'Ambientes de desenvolvimento na nuvem (Google Colab, AWS Sagemaker, Kaggle Notebooks etc)')  \
# 2640                                                NaN
# 2641                                                0.0
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_c_e ', 'Ferramentas de AutoML (Datarobot, H2O, Auto-Keras etc)')  \
# 2640                                                NaN
# 2641                                                0.0
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_c_f ', 'Ferramentas de ETL (Apache Airflow, NiFi, Stitch, Fivetran, Pentaho etc)')  \
# 2640                                                NaN
# 2641                                                0.0
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_c_g ', 'Plataformas de Machine Learning (TensorFlow, Azure Machine Learning, Kubeflow etc)')  \
# 2640                                                NaN
# 2641                                                0.0
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_c_h ', 'Feature Store (Feast, Hopsworks, AWS Feature Store, Databricks Feature Store etc)')  \
# 2640                                                NaN
# 2641                                                0.0
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_c_i ', 'Sistemas de controle de versão (Github, DVC, Neptune, Gitlab etc)')  \
# 2640                                                NaN
# 2641                                                0.0
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_c_j ', 'Plataformas de Data Apps (Streamlit, Shiny, Plotly Dash etc)')  \
# 2640                                                NaN
# 2641                                                1.0
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_c_k ', 'Ferramentas de estatística avançada como SPSS, SAS, etc.')  \
# 2640                                                NaN
# 2641                                                0.0
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_c_l ', 'Não utilizo nenhuma dessas ferramentas no meu dia a dia.')  \
# 2640                                                NaN
# 2641                                                0.0
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P8_d ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo no trabalho?')  \
# 2640                                                NaN
# 2641  Estudos Ad-hoc com o objetivo de confirmar hip...
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_d_a ', 'Coletando e limpando os dados que uso para análise e modelagem.')  \
# 2640                                                NaN
# 2641                                                0.0
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_d_b ', 'Entrando em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')  \
# 2640                                                NaN
# 2641                                                0.0
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_d_c ', 'Desenvolvendo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')  \
# 2640                                                NaN
# 2641                                                0.0
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_d_d ', 'Colocando modelos em produção, criando os pipelines de dados, APIs de consumo e monitoramento.')  \
# 2640                                                NaN
# 2641                                                1.0
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_d_e ', 'Cuidando da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.')  \
# 2640                                                NaN
# 2641                                                0.0
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_d_f ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc.')  \
# 2640                                                NaN
# 2641                                                0.0
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_d_g ', 'Criando e dando manutenção em ETLs, DAGs e automações de pipelines de dados.')  \
# 2640                                                NaN
# 2641                                                0.0
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_d_h ', 'Criando e gerenciando soluções de Feature Store e cultura de MLOps.')  \
# 2640                                                NaN
# 2641                                                0.0
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_d_i ', 'Criando e mantendo a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')  \
# 2640                                                NaN
# 2641                                                0.0
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P9_a ', 'Quais das iniciativas do Data Hackers que você já acessou/acompanhou?')  \
# 2640                  Ainda não conhecia o Data Hackers
# 2641                        Blog/Medium do Data Hackers
# 2642  Blog/Medium do Data Hackers, Podcast do Data H...
# 2643                        Blog/Medium do Data Hackers
# 2644                  Ainda não conhecia o Data Hackers
#
#       ('P9_a_a ', 'Blog/Medium do Data Hackers')  \
# 2640                                           0
# 2641                                           1
# 2642                                           1
# 2643                                           1
# 2644                                           0
#
#       ('P9_a_b ', 'Podcast do Data Hackers')  \
# 2640                                       0
# 2641                                       0
# 2642                                       1
# 2643                                       0
# 2644                                       0
#
#       ('P9_a_d ', 'Newsletter Semanal')  ('P9_a_e ', 'Canal do Slack')  \
# 2640                                  0                              0
# 2641                                  0                              0
# 2642                                  1                              1
# 2643                                  0                              0
# 2644                                  0                              0
#
#       ('P9_a_f ', 'Canal do Youtube do Data Hackers')  \
# 2640                                                0
# 2641                                                0
# 2642                                                0
# 2643                                                0
# 2644                                                0
#
#       ('P9_a_g ', 'Ainda não conhecia o Data Hackers')
# 2640                                                 1
# 2641                                                 0
# 2642                                                 0
# 2643                                                 0
# 2644                                                 1

# %% [markdown]
# Olhando para as primeiras e as últimas linhas, é possível notar que as informações sóciodemográficas estão bem preenchidas. Uma ótima informação, pois assim conseguimos analisar as diversas localizações da área de dados no Brasil.

# %%
df.sample(10)
# Out:
#                           ('P0', 'id')  ('P1_a ', 'Idade')  \
# 529   z4m2k3xy0gq68a8w0eowfbrz4m2kgckw                45.0
# 1324  lrarmqgfuuziwymu63xslraruf1t62xo                35.0
# 2582  1deeluaxvf85plqh31deelu1x5q21n3e                28.0
# 309   g51outixbfkvw9clo6g512i01iqq394z                26.0
# 910   smob9r856g58mwegizdvfsmob94m8tu9                30.0
# 1354  l5yb34z691gp0s1lvw8zl5yb34z69o4r                21.0
# 401   75z6t1ug11cc8r2u75z6t1bonmn7rb2e                43.0
# 1738  pxromor8fgmwf0lw7mkxpxru5dr6gris                29.0
# 110   ym7epuig4btcyl81w6cfofiym7epui2f                41.0
# 1450  ymzk9qykx29eqmi1gy50r3fbymzk9qy9                20.0
#
#      ('P1_a_a ', 'Faixa idade') ('P1_b ', 'Genero')  \
# 529                       45-49           Masculino
# 1324                      35-39           Masculino
# 2582                      25-29           Masculino
# 309                       25-29           Masculino
# 910                       30-34            Feminino
# 1354                      17-21           Masculino
# 401                       40-44           Masculino
# 1738                      25-29           Masculino
# 110                       40-44           Masculino
# 1450                      17-21           Masculino
#
#      ('P1_e ', 'Estado onde mora') ('P1_e_a ', 'uf onde mora')  \
# 529                 São Paulo (SP)                          SP
# 1324                   Paraná (PR)                          PR
# 2582                Fora do Brasil                    Exterior
# 309                 São Paulo (SP)                          SP
# 910                            NaN                         NaN
# 1354                São Paulo (SP)                          SP
# 401                 São Paulo (SP)                          SP
# 1738                São Paulo (SP)                          SP
# 110                 São Paulo (SP)                          SP
# 1450                    Piauí (PI)                          PI
#
#      ('P1_e_b ', 'Regiao onde mora') ('P1_g_b ', 'Regiao de origem')  \
# 529                          Sudeste                             NaN
# 1324                             Sul                             Sul
# 2582                        Exterior                             NaN
# 309                          Sudeste                             NaN
# 910                            Norte                             NaN
# 1354                         Sudeste                             NaN
# 401                          Sudeste                             NaN
# 1738                         Sudeste                             NaN
# 110                          Sudeste                             NaN
# 1450                        Nordeste                             NaN
#
#       ('P1_g_c ', 'Mudou de Estado?') ('P1_h ', 'Nivel de Ensino')  \
# 529                                 0        Graduação/Bacharelado
# 1324                                1                Pós-graduação
# 2582                                0        Graduação/Bacharelado
# 309                                 0        Graduação/Bacharelado
# 910                                 0                Pós-graduação
# 1354                                0        Graduação/Bacharelado
# 401                                 0        Graduação/Bacharelado
# 1738                                0        Graduação/Bacharelado
# 110                                 0                Pós-graduação
# 1450                                0       Estudante de Graduação
#
#                           ('P1_i ', 'Área de Formação')  \
# 529   Computação / Engenharia de Software / Sistemas...
# 1324  Computação / Engenharia de Software / Sistemas...
# 2582  Computação / Engenharia de Software / Sistemas...
# 309   Computação / Engenharia de Software / Sistemas...
# 910                                  Outras Engenharias
# 1354  Computação / Engenharia de Software / Sistemas...
# 401   Computação / Engenharia de Software / Sistemas...
# 1738                                 Outras Engenharias
# 110   Computação / Engenharia de Software / Sistemas...
# 1450                                 Outras Engenharias
#
#      ('P2_a ', 'Qual sua situação atual de trabalho?')  \
# 529                                   Servidor Público
# 1324                                   Empregado (CLT)
# 2582                Desempregado, buscando recolocação
# 309                                    Empregado (CLT)
# 910                                    Empregado (CLT)
# 1354                                   Empregado (CLT)
# 401                   Empreendedor ou Empregado (CNPJ)
# 1738                Desempregado, buscando recolocação
# 110                                    Empregado (CLT)
# 1450                     Somente Estudante (graduação)
#
#                   ('P2_b ', 'Setor') ('P2_c ', 'Numero de Funcionarios')  \
# 529                    Área da Saúde                      de 1001 a 3000
# 1324                        Educação                       de 501 a 1000
# 2582                             NaN                                 NaN
# 309                        Marketing                       de 501 a 1000
# 910                           Varejo                       Acima de 3000
# 1354  Tecnologia/Fábrica de Software                        de 101 a 500
# 401   Tecnologia/Fábrica de Software                           de 6 a 10
# 1738                             NaN                                 NaN
# 110                           Varejo                        de 101 a 500
# 1450                             NaN                                 NaN
#
#       ('P2_d ', 'Gestor?')             ('P2_e ', 'Cargo como Gestor')  \
# 529                    0.0                                        NaN
# 1324                   0.0                                        NaN
# 2582                   NaN                                        NaN
# 309                    1.0                    Team Leader/Tech Leader
# 910                    0.0                                        NaN
# 1354                   0.0                                        NaN
# 401                    1.0  Sócio ou C-level (CEO, CDO, CIO, CTO etc)
# 1738                   NaN                                        NaN
# 110                    1.0  Sócio ou C-level (CEO, CDO, CIO, CTO etc)
# 1450                   NaN                                        NaN
#
#                           ('P2_f ', 'Cargo Atual') ('P2_g ', 'Nivel')  \
# 529                                          Outro             Júnior
# 1324  Analista de BI/BI Analyst/Analytics Engineer             Sênior
# 2582                                           NaN                NaN
# 309                                            NaN                NaN
# 910                 Analista de Dados/Data Analyst             Júnior
# 1354    Engenheiro de Machine Learning/ML Engineer              Pleno
# 401                                            NaN                NaN
# 1738                                           NaN                NaN
# 110                                            NaN                NaN
# 1450                                           NaN                NaN
#
#            ('P2_h ', 'Faixa salarial')  \
# 529     de R$ 1.001/mês a R$ 2.000/mês
# 1324    de R$ 4.001/mês a R$ 6.000/mês
# 2582                               NaN
# 309    de R$ 8.001/mês a R$ 12.000/mês
# 910      de R$ 2.001/mês a R$ 3000/mês
# 1354    de R$ 3.001/mês a R$ 4.000/mês
# 401   de R$ 16.001/mês a R$ 20.000/mês
# 1738                               NaN
# 110   de R$ 30.001/mês a R$ 40.000/mês
# 1450                               NaN
#
#      ('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')  \
# 529              Não tenho experiência na área de dados
# 1324                                    Mais de 10 anos
# 2582                                                NaN
# 309                                       de 2 a 3 anos
# 910                                       de 1 a 2 anos
# 1354                                      de 2 a 3 anos
# 401                                     Mais de 10 anos
# 1738                                                NaN
# 110                                     Mais de 10 anos
# 1450                                                NaN
#
#      ('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')  \
# 529   Não tive experiência na área de TI/Engenharia ...
# 1324                                    Mais de 10 anos
# 2582                                                NaN
# 309                                       de 4 a 5 anos
# 910   Não tive experiência na área de TI/Engenharia ...
# 1354                                      de 2 a 3 anos
# 401                                      de 6 a 10 anos
# 1738                                                NaN
# 110                                      de 6 a 10 anos
# 1450                                                NaN
#
#       ('P2_k ', 'Você está satisfeito na sua empresa atual?')  \
# 529                                                 0.0
# 1324                                                1.0
# 2582                                                NaN
# 309                                                 1.0
# 910                                                 1.0
# 1354                                                0.0
# 401                                                 1.0
# 1738                                                NaN
# 110                                                 1.0
# 1450                                                NaN
#
#      ('P2_l ', 'Qual o principal motivo da sua insatisfação com a empresa atual?')  \
# 529   Falta de oportunidade de crescimento no empreg...
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 NaN
# 910                                                 NaN
# 1354  Falta de maturidade analítica na empresa, Salá...
# 401                                                 NaN
# 1738                                                NaN
# 110                                                 NaN
# 1450                                                NaN
#
#       ('P2_l_a ', 'Falta de oportunidade de crescimento no emprego atual')  \
# 529                                                 1.0
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 NaN
# 910                                                 NaN
# 1354                                                0.0
# 401                                                 NaN
# 1738                                                NaN
# 110                                                 NaN
# 1450                                                NaN
#
#       ('P2_l_b ', 'Salário atual não corresponde ao mercado')  \
# 529                                                 0.0
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 NaN
# 910                                                 NaN
# 1354                                                1.0
# 401                                                 NaN
# 1738                                                NaN
# 110                                                 NaN
# 1450                                                NaN
#
#       ('P2_l_c ', 'Não tenho uma boa relação com meu líder/gestor')  \
# 529                                                 0.0
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 NaN
# 910                                                 NaN
# 1354                                                0.0
# 401                                                 NaN
# 1738                                                NaN
# 110                                                 NaN
# 1450                                                NaN
#
#       ('P2_l_d ', 'Gostaria de trabalhar em em outra área de atuação')  \
# 529                                                 1.0
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 NaN
# 910                                                 NaN
# 1354                                                1.0
# 401                                                 NaN
# 1738                                                NaN
# 110                                                 NaN
# 1450                                                NaN
#
#       ('P2_l_e ', 'Gostaria de receber mais benefícios')  \
# 529                                                 0.0
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 NaN
# 910                                                 NaN
# 1354                                                0.0
# 401                                                 NaN
# 1738                                                NaN
# 110                                                 NaN
# 1450                                                NaN
#
#       ('P2_l_f ', 'O clima de trabalho/ambiente não é bom')  \
# 529                                                 0.0
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 NaN
# 910                                                 NaN
# 1354                                                0.0
# 401                                                 NaN
# 1738                                                NaN
# 110                                                 NaN
# 1450                                                NaN
#
#       ('P2_l_g ', 'Falta de maturidade analítica na empresa')  \
# 529                                                 1.0
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 NaN
# 910                                                 NaN
# 1354                                                1.0
# 401                                                 NaN
# 1738                                                NaN
# 110                                                 NaN
# 1450                                                NaN
#
#      ('P2_m ', 'Você participou de entrevistas de emprego nos últimos 6 meses?')  \
# 529   Não participei de entrevistas de empregos/proc...
# 1324  Não participei de entrevistas de empregos/proc...
# 2582                                                NaN
# 309                Sim, fui aprovado e mudei de emprego
# 910   Sim, fui aprovado mas decidi não mudar de emprego
# 1354  Sim, fui aprovado mas decidi não mudar de emprego
# 401           Sim, fiz entrevistas mas não fui aprovado
# 1738                                                NaN
# 110   Não participei de entrevistas de empregos/proc...
# 1450                                                NaN
#
#      ('P2_n ', 'Você pretende mudar de emprego nos próximos 6 meses?')  \
# 529   Não estou buscando, mas me considero aberto a ...
# 1324  Não estou buscando, mas me considero aberto a ...
# 2582                                                NaN
# 309   Não estou buscando e não pretendo mudar de emp...
# 910   Estou em busca de oportunidades dentro ou fora...
# 1354  Estou em busca de oportunidades dentro ou fora...
# 401   Não estou buscando, mas me considero aberto a ...
# 1738                                                NaN
# 110   Estou em busca de oportunidades dentro ou fora...
# 1450                                                NaN
#
#      ('P2_o ', 'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?')  \
# 529   Propósito do trabalho e da empresa, Oportunida...
# 1324  Plano de carreira e oportunidades de crescimen...
# 2582                                                NaN
# 309   Oportunidade de aprendizado e trabalhar com re...
# 910   Remuneração/Salário, Benefícios, Propósito do ...
# 1354  Oportunidade de aprendizado e trabalhar com re...
# 401   Remuneração/Salário, Flexibilidade de trabalho...
# 1738                                                NaN
# 110   Propósito do trabalho e da empresa, Oportunida...
# 1450                                                NaN
#
#       ('P2_o_a ', 'Remuneração/Salário')  ('P2_o_b ', 'Benefícios')  \
# 529                                  0.0                        0.0
# 1324                                 1.0                        0.0
# 2582                                 NaN                        NaN
# 309                                  1.0                        0.0
# 910                                  1.0                        1.0
# 1354                                 0.0                        0.0
# 401                                  1.0                        0.0
# 1738                                 NaN                        NaN
# 110                                  0.0                        0.0
# 1450                                 NaN                        NaN
#
#       ('P2_o_c ', 'Propósito do trabalho e da empresa')  \
# 529                                                 1.0
# 1324                                                1.0
# 2582                                                NaN
# 309                                                 0.0
# 910                                                 1.0
# 1354                                                0.0
# 401                                                 0.0
# 1738                                                NaN
# 110                                                 1.0
# 1450                                                NaN
#
#       ('P2_o_d ', 'Flexibilidade de trabalho remoto')  \
# 529                                               0.0
# 1324                                              0.0
# 2582                                              NaN
# 309                                               0.0
# 910                                               0.0
# 1354                                              0.0
# 401                                               1.0
# 1738                                              NaN
# 110                                               0.0
# 1450                                              NaN
#
#       ('P2_o_e ', 'Ambiente e clima de trabalho')  \
# 529                                           0.0
# 1324                                          0.0
# 2582                                          NaN
# 309                                           1.0
# 910                                           0.0
# 1354                                          0.0
# 401                                           0.0
# 1738                                          NaN
# 110                                           0.0
# 1450                                          NaN
#
#       ('P2_o_f ', 'Oportunidade de aprendizado e trabalhar com referências na área')  \
# 529                                                 1.0
# 1324                                                0.0
# 2582                                                NaN
# 309                                                 1.0
# 910                                                 0.0
# 1354                                                1.0
# 401                                                 1.0
# 1738                                                NaN
# 110                                                 1.0
# 1450                                                NaN
#
#       ('P2_o_g ', 'Plano de carreira e oportunidades de crescimento profissional')  \
# 529                                                 1.0
# 1324                                                1.0
# 2582                                                NaN
# 309                                                 0.0
# 910                                                 0.0
# 1354                                                1.0
# 401                                                 0.0
# 1738                                                NaN
# 110                                                 0.0
# 1450                                                NaN
#
#       ('P2_o_h ', 'Maturidade da empresa em termos de tecnologia e dados')  \
# 529                                                 0.0
# 1324                                                0.0
# 2582                                                NaN
# 309                                                 0.0
# 910                                                 0.0
# 1354                                                1.0
# 401                                                 0.0
# 1738                                                NaN
# 110                                                 0.0
# 1450                                                NaN
#
#       ('P2_o_i ', 'Qualidade dos gestores e líderes')  \
# 529                                               0.0
# 1324                                              0.0
# 2582                                              NaN
# 309                                               0.0
# 910                                               0.0
# 1354                                              0.0
# 401                                               0.0
# 1738                                              NaN
# 110                                               1.0
# 1450                                              NaN
#
#       ('P2_o_j ', 'Reputação que a empresa tem no mercado')  \
# 529                                                 0.0
# 1324                                                0.0
# 2582                                                NaN
# 309                                                 0.0
# 910                                                 0.0
# 1354                                                0.0
# 401                                                 0.0
# 1738                                                NaN
# 110                                                 0.0
# 1450                                                NaN
#
#      ('P2_q ', 'Atualmente qual a sua forma de trabalho?')  \
# 529                              Modelo 100% presencial
# 1324                             Modelo 100% presencial
# 2582                                                NaN
# 309                                  Modelo 100% remoto
# 910   Modelo híbrido flexível (o funcionário tem lib...
# 1354                                 Modelo 100% remoto
# 401                                  Modelo 100% remoto
# 1738                                                NaN
# 110                                  Modelo 100% remoto
# 1450                                                NaN
#
#      ('P2_r ', 'Qual a forma de trabalho ideal para você?')  \
# 529   Modelo híbrido flexível (o funcionário tem lib...
# 1324  Modelo híbrido com dias fixos de trabalho pres...
# 2582                                                NaN
# 309   Modelo híbrido flexível (o funcionário tem lib...
# 910   Modelo híbrido flexível (o funcionário tem lib...
# 1354  Modelo híbrido flexível (o funcionário tem lib...
# 401   Modelo híbrido flexível (o funcionário tem lib...
# 1738                                                NaN
# 110   Modelo híbrido flexível (o funcionário tem lib...
# 1450                                                NaN
#
#      ('P2_s ', 'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?')  \
# 529   Vou aceitar e retornar ao modelo 100% presencial.
# 1324  Vou aceitar e retornar ao modelo 100% presencial.
# 2582                                                NaN
# 309   Vou procurar outra oportunidade no modelo híbr...
# 910   Vou procurar outra oportunidade no modelo híbr...
# 1354  Vou procurar outra oportunidade no modelo híbr...
# 401   Vou procurar outra oportunidade no modelo híbr...
# 1738                                                NaN
# 110   Vou procurar outra oportunidade no modelo híbr...
# 1450                                                NaN
#
#      ('P3_a ', 'Qual o número aproximado de pessoas que atuam com dados na sua empresa hoje?')  \
# 529                                                 NaN
# 1324                                                NaN
# 2582                                                NaN
# 309                                             11 - 20
# 910                                                 NaN
# 1354                                                NaN
# 401                                               1 - 3
# 1738                                                NaN
# 110                                            51 - 100
# 1450                                                NaN
#
#      ('P3_b ', 'Quais desses papéis/cargos fazem parte do time (ou chapter) de dados da sua empresa?')  \
# 529                                                 NaN
# 1324                                                NaN
# 2582                                                NaN
# 309   Cientista de Dados/Data Scientist, Analytics E...
# 910                                                 NaN
# 1354                                                NaN
# 401   Database Administrator/DBA, Engenharia de Dado...
# 1738                                                NaN
# 110   Analista de Dados/Data Analyst, Analytics Engi...
# 1450                                                NaN
#
#       ('P3_b_a ', 'Analytics Engineer')  \
# 529                                 NaN
# 1324                                NaN
# 2582                                NaN
# 309                                 1.0
# 910                                 NaN
# 1354                                NaN
# 401                                 0.0
# 1738                                NaN
# 110                                 1.0
# 1450                                NaN
#
#       ('P3_b_b ', 'Engenharia de Dados/Data Engineer')  \
# 529                                                NaN
# 1324                                               NaN
# 2582                                               NaN
# 309                                                1.0
# 910                                                NaN
# 1354                                               NaN
# 401                                                1.0
# 1738                                               NaN
# 110                                                1.0
# 1450                                               NaN
#
#       ('P3_b_c ', 'Analista de Dados/Data Analyst')  \
# 529                                             NaN
# 1324                                            NaN
# 2582                                            NaN
# 309                                             0.0
# 910                                             NaN
# 1354                                            NaN
# 401                                             0.0
# 1738                                            NaN
# 110                                             1.0
# 1450                                            NaN
#
#       ('P3_b_d ', 'Cientista de Dados/Data Scientist')  \
# 529                                                NaN
# 1324                                               NaN
# 2582                                               NaN
# 309                                                1.0
# 910                                                NaN
# 1354                                               NaN
# 401                                                1.0
# 1738                                               NaN
# 110                                                1.0
# 1450                                               NaN
#
#       ('P3_b_e ', 'Database Administrator/DBA')  \
# 529                                         NaN
# 1324                                        NaN
# 2582                                        NaN
# 309                                         0.0
# 910                                         NaN
# 1354                                        NaN
# 401                                         1.0
# 1738                                        NaN
# 110                                         0.0
# 1450                                        NaN
#
#       ('P3_b_f ', 'Analista de Business Intelligence/BI')  \
# 529                                                 NaN
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 0.0
# 910                                                 NaN
# 1354                                                NaN
# 401                                                 0.0
# 1738                                                NaN
# 110                                                 1.0
# 1450                                                NaN
#
#       ('P3_b_g ', 'Arquiteto de Dados/Data Architect')  \
# 529                                                NaN
# 1324                                               NaN
# 2582                                               NaN
# 309                                                0.0
# 910                                                NaN
# 1354                                               NaN
# 401                                                1.0
# 1738                                               NaN
# 110                                                1.0
# 1450                                               NaN
#
#       ('P3_b_h ', 'Data Product Manager/DPM')  \
# 529                                       NaN
# 1324                                      NaN
# 2582                                      NaN
# 309                                       1.0
# 910                                       NaN
# 1354                                      NaN
# 401                                       0.0
# 1738                                      NaN
# 110                                       0.0
# 1450                                      NaN
#
#       ('P3_b_i ', 'Business Analyst')  \
# 529                               NaN
# 1324                              NaN
# 2582                              NaN
# 309                               0.0
# 910                               NaN
# 1354                              NaN
# 401                               0.0
# 1738                              NaN
# 110                               1.0
# 1450                              NaN
#
#      ('P3_c ', 'Quais dessas responsabilidades fazem parte da sua rotina atual de trabalho como gestor?')  \
# 529                                                 NaN
# 1324                                                NaN
# 2582                                                NaN
# 309   Pensar na visão de longo prazo de dados da emp...
# 910                                                 NaN
# 1354                                                NaN
# 401   Pensar na visão de longo prazo de dados da emp...
# 1738                                                NaN
# 110   Pensar na visão de longo prazo de dados da emp...
# 1450                                                NaN
#
#       ('P3_c_a ', 'Pensar na visão de longo prazo de dados da empresa e fortalecimento da cultura analítica da companhia.')  \
# 529                                                 NaN
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 1.0
# 910                                                 NaN
# 1354                                                NaN
# 401                                                 1.0
# 1738                                                NaN
# 110                                                 1.0
# 1450                                                NaN
#
#       ('P3_c_b ', 'Organização de treinamentos e iniciativas com o objetivo de aumentar a maturidade analítica das áreas de negócios.')  \
# 529                                                 NaN
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 0.0
# 910                                                 NaN
# 1354                                                NaN
# 401                                                 0.0
# 1738                                                NaN
# 110                                                 1.0
# 1450                                                NaN
#
#       ('P3_c_c ', 'Atração, seleção e contratação de talentos para o time de dados.')  \
# 529                                                 NaN
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 1.0
# 910                                                 NaN
# 1354                                                NaN
# 401                                                 0.0
# 1738                                                NaN
# 110                                                 1.0
# 1450                                                NaN
#
#       ('P3_c_d ', 'Decisão sobre contratação de ferramentas e tecnologias relacionadas a dados.')  \
# 529                                                 NaN
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 1.0
# 910                                                 NaN
# 1354                                                NaN
# 401                                                 1.0
# 1738                                                NaN
# 110                                                 1.0
# 1450                                                NaN
#
#       ('P3_c_e ', 'Sou gestor da equipe responsável pela engenharia de dados e por manter o Data Lake da empresa como fonte única dos dados, garantindo a qualidade e confiabilidade da informação.')  \
# 529                                                 NaN
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 0.0
# 910                                                 NaN
# 1354                                                NaN
# 401                                                 1.0
# 1738                                                NaN
# 110                                                 1.0
# 1450                                                NaN
#
#       ('P3_c_f ', 'Sou gestor da equipe responsável pela entrega de dados, estudos, relatórios e dashboards para as áreas de negócio da empresa.')  \
# 529                                                 NaN
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 1.0
# 910                                                 NaN
# 1354                                                NaN
# 401                                                 0.0
# 1738                                                NaN
# 110                                                 1.0
# 1450                                                NaN
#
#       ('P3_c_g ', 'Sou gestor da equipe responsável por iniciativas e projetos envolvendo Inteligência Artificial e Machine Learning.')  \
# 529                                                 NaN
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 0.0
# 910                                                 NaN
# 1354                                                NaN
# 401                                                 0.0
# ...
# 309                                                 NaN
# 910                                                 NaN
# 1354                                                0.0
# 401                                                 NaN
# 1738                                                NaN
# 110                                                 NaN
# 1450                                                NaN
#
#       ('P8_d_b ', 'Entrando em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')  \
# 529                                                 NaN
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 NaN
# 910                                                 NaN
# 1354                                                0.0
# 401                                                 NaN
# 1738                                                NaN
# 110                                                 NaN
# 1450                                                NaN
#
#       ('P8_d_c ', 'Desenvolvendo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')  \
# 529                                                 NaN
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 NaN
# 910                                                 NaN
# 1354                                                1.0
# 401                                                 NaN
# 1738                                                NaN
# 110                                                 NaN
# 1450                                                NaN
#
#       ('P8_d_d ', 'Colocando modelos em produção, criando os pipelines de dados, APIs de consumo e monitoramento.')  \
# 529                                                 NaN
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 NaN
# 910                                                 NaN
# 1354                                                1.0
# 401                                                 NaN
# 1738                                                NaN
# 110                                                 NaN
# 1450                                                NaN
#
#       ('P8_d_e ', 'Cuidando da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.')  \
# 529                                                 NaN
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 NaN
# 910                                                 NaN
# 1354                                                0.0
# 401                                                 NaN
# 1738                                                NaN
# 110                                                 NaN
# 1450                                                NaN
#
#       ('P8_d_f ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc.')  \
# 529                                                 NaN
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 NaN
# 910                                                 NaN
# 1354                                                0.0
# 401                                                 NaN
# 1738                                                NaN
# 110                                                 NaN
# 1450                                                NaN
#
#       ('P8_d_g ', 'Criando e dando manutenção em ETLs, DAGs e automações de pipelines de dados.')  \
# 529                                                 NaN
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 NaN
# 910                                                 NaN
# 1354                                                0.0
# 401                                                 NaN
# 1738                                                NaN
# 110                                                 NaN
# 1450                                                NaN
#
#       ('P8_d_h ', 'Criando e gerenciando soluções de Feature Store e cultura de MLOps.')  \
# 529                                                 NaN
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 NaN
# 910                                                 NaN
# 1354                                                0.0
# 401                                                 NaN
# 1738                                                NaN
# 110                                                 NaN
# 1450                                                NaN
#
#       ('P8_d_i ', 'Criando e mantendo a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')  \
# 529                                                 NaN
# 1324                                                NaN
# 2582                                                NaN
# 309                                                 NaN
# 910                                                 NaN
# 1354                                                0.0
# 401                                                 NaN
# 1738                                                NaN
# 110                                                 NaN
# 1450                                                NaN
#
#      ('P9_a ', 'Quais das iniciativas do Data Hackers que você já acessou/acompanhou?')  \
# 529                   Ainda não conhecia o Data Hackers
# 1324  Podcast do Data Hackers, Newsletter Semanal, B...
# 2582                  Ainda não conhecia o Data Hackers
# 309   Canal do Slack, Canal do Youtube do Data Hacke...
# 910                         Blog/Medium do Data Hackers
# 1354  Podcast do Data Hackers, Blog/Medium do Data H...
# 401   Blog/Medium do Data Hackers, Podcast do Data H...
# 1738            Podcast do Data Hackers, Canal do Slack
# 110                   Ainda não conhecia o Data Hackers
# 1450  Blog/Medium do Data Hackers, Podcast do Data H...
#
#       ('P9_a_a ', 'Blog/Medium do Data Hackers')  \
# 529                                            0
# 1324                                           1
# 2582                                           0
# 309                                            0
# 910                                            1
# 1354                                           1
# 401                                            1
# 1738                                           0
# 110                                            0
# 1450                                           1
#
#       ('P9_a_b ', 'Podcast do Data Hackers')  \
# 529                                        0
# 1324                                       1
# 2582                                       0
# 309                                        1
# 910                                        0
# 1354                                       1
# 401                                        1
# 1738                                       1
# 110                                        0
# 1450                                       1
#
#       ('P9_a_d ', 'Newsletter Semanal')  ('P9_a_e ', 'Canal do Slack')  \
# 529                                   0                              0
# 1324                                  1                              0
# 2582                                  0                              0
# 309                                   1                              1
# 910                                   0                              0
# 1354                                  0                              0
# 401                                   1                              1
# 1738                                  0                              1
# 110                                   0                              0
# 1450                                  1                              1
#
#       ('P9_a_f ', 'Canal do Youtube do Data Hackers')  \
# 529                                                 0
# 1324                                                0
# 2582                                                0
# 309                                                 1
# 910                                                 0
# 1354                                                0
# 401                                                 1
# 1738                                                0
# 110                                                 0
# 1450                                                0
#
#       ('P9_a_g ', 'Ainda não conhecia o Data Hackers')
# 529                                                  1
# 1324                                                 0
# 2582                                                 1
# 309                                                  0
# 910                                                  0
# 1354                                                 0
# 401                                                  0
# 1738                                                 0
# 110                                                  1
# 1450                                                 0

# %% [markdown]
# Analisando as colunas, é possível visualizar que a quantidade de *missing values* é grande. No entanto, é comprensivel que não exista tantos valores válidos por existirem perguntas específicas.
#
# Se não existisse valores nulos não seria um desafio, né?!
#
# Assim que eu fiz a leitura do conjunto de dados, o pandas me retornou a mensagem de atenção *DtypeWarning: Columns (47) have mixed types*. Isso significa que o Pandas não conseguiu identificar corretamente o tipo de dados das 47 variáveis em questão.
#
# O próximo passo será identificar o tipo de dados das variáveis e buscar corrigir este aviso que o Pandas retornou.

# %%
#dataframe de cópia
df_clean = df.copy()

# %%
columns = list(df_clean.columns)

# %%
for column in range(len(columns)):
  columns[column].replace(r'\\', '') #alterar uma das opções da pergunta 7

# %%
#função para separar as perguntas em Dataframes distintos

def separate_df(n_pattern):
  aux_cols = []
  df_aux = pd.DataFrame()
  df_aux["('P0', 'id')"] = df_clean["('P0', 'id')"] #adiciona o ID em todos os dataframes

  for column in columns:

    if re.search(f"^\('\w[{n_pattern}]_", column): #expressão regular simples para identificar as diversas perguntas
      aux_cols.append(column)  
  
  for col in aux_cols:
    df_aux[col] = df_clean[col]
  
  return df_aux

# %% [markdown]
# Com a divisão das perguntas em dataframes, é possível analisar com mais profundidade cada pergunta.

# %%
df_p1 = separate_df(1); df_p2 = separate_df(2); df_p3 = separate_df(3); df_p4 = separate_df(4); df_p5 = separate_df(5); df_p6 = separate_df(6)
df_p7 = separate_df(7); df_p8 = separate_df(8); df_p9 = separate_df(9);
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`

# %% [markdown]
# ## **Dataframe (Conjunto de Perguntas - 01)**
#
# Antes de iniciar a análise eu irei renomear as variáveis para facilitar o acesso para quando for necessário localizar determinados dados.

# %%
df_p1.rename(columns= {"('P0', 'id')" : 'P0 : ID', "('P1_a ', 'Idade')" : 'P1_A : Idade',  "('P1_a_a ', 'Faixa idade')" : 'P1_A_A : Faixa Idade', 
                       "('P1_b ', 'Genero')" : 'P1_B : Genero', "('P1_e ', 'Estado onde mora')" : 'P1_E : Estado Onde Mora',
                       "('P1_e_a ', 'uf onde mora')" : 'P1_E_A : UF Onde Mora', "('P1_e_b ', 'Regiao onde mora')" : 'P1_E_B : Regiao Onde Mora', 
                       "('P1_g_b ', 'Regiao de origem')" : 'P1_G_B : Regiao de Origem', "('P1_g_c ', 'Mudou de Estado?')" : 'P1_G_C : Mudou de Estado?', 
                       "('P1_h ', 'Nivel de Ensino')" : 'P1_H : Nivel de Ensino', "('P1_i ', 'Área de Formação')" : 'P1_I : Area de Formacao'}, inplace=True)

# %% [markdown]
# Depois de renomear as colunas, vou verificar como estão as primeiras e últimas linhas deste dataframe. Uma ótima função do Pandas no momentos iniciais da análise é a `.sample()`, onde é possível visualizar linhas randomizadas do dataframe.

# %%
df_p1.head(2)
# Out:
#                             P0 : ID  P1_A : Idade P1_A_A : Faixa Idade  \
# 0  qkx4q0ei90wcjxnqkx4q0j3xgf0zn13s          38.0                35-39
# 1  zdl2n19yhgpnoaco6kkczdl2nwv9zwrt          39.0                35-39
#
#   P1_B : Genero P1_E : Estado Onde Mora P1_E_A : UF Onde Mora  \
# 0     Masculino              Ceará (CE)                    CE
# 1     Masculino              Bahia (BA)                    BA
#
#   P1_E_B : Regiao Onde Mora P1_G_B : Regiao de Origem  \
# 0                  Nordeste                       NaN
# 1                  Nordeste                   Sudeste
#
#    P1_G_C : Mudou de Estado? P1_H : Nivel de Ensino  \
# 0                          0          Pós-graduação
# 1                          1          Pós-graduação
#
#                              P1_I : Area de Formacao
# 0                                   Química / Física
# 1  Economia/ Administração / Contabilidade / Fina...

# %%
df_p1.tail(2)
# Out:
#                                P0 : ID  P1_A : Idade P1_A_A : Faixa Idade  \
# 2643  075h3v2z19if04yn7o075h3vhifl38rw          38.0                35-39
# 2644  037usz1h2yip96dgil4mhj037uszw1gk          27.0                25-29
#
#      P1_B : Genero P1_E : Estado Onde Mora P1_E_A : UF Onde Mora  \
# 2643     Masculino     Rio de Janeiro (RJ)                    RJ
# 2644      Feminino       Minas Gerais (MG)                    MG
#
#      P1_E_B : Regiao Onde Mora P1_G_B : Regiao de Origem  \
# 2643                   Sudeste                       NaN
# 2644                   Sudeste                       NaN
#
#       P1_G_C : Mudou de Estado? P1_H : Nivel de Ensino  \
# 2643                          0  Graduação/Bacharelado
# 2644                          0          Pós-graduação
#
#                                 P1_I : Area de Formacao
# 2643  Computação / Engenharia de Software / Sistemas...
# 2644                                             Outras

# %%
df_p1.sample(10)
# Out:
#                                P0 : ID  P1_A : Idade P1_A_A : Faixa Idade  \
# 2213  7097vzp36ujhsqqjnpa1g7097vdnawco          33.0                30-34
# 1761  p0egx9s2z6pswf0rett0wp0egx9s2s08          30.0                30-34
# 2300  5lgrw03hswb2v5lgreerku5xzj6x07c5          38.0                35-39
# 1850  mf4oupwgnofcobz42camf4oupjtyra5u          30.0                30-34
# 1897  ccvki2qa36kz82fw1ccvkij3uil0wy1g          24.0                22-24
# 1760  e7p0kyrpt0cwcok8haje7p0kwx9baamb          29.0                25-29
# 1427  jvxsysqao4qqyokijvxsynpwwmbx452r          32.0                30-34
# 892   9puscp4on3rotm9pusceae4lkn6j9qpy          27.0                25-29
# 2209  dr2r685fab1yjknr3u9rfkdr2r685szn          27.0                25-29
# 392   torzjrgvvdq0v9d6tr24torzjmtlrhx7          49.0                45-49
#
#      P1_B : Genero P1_E : Estado Onde Mora P1_E_A : UF Onde Mora  \
# 2213     Masculino          São Paulo (SP)                    SP
# 1761      Feminino       Minas Gerais (MG)                    MG
# 2300     Masculino          São Paulo (SP)                    SP
# 1850      Feminino          Fora do Brasil              Exterior
# 1897      Feminino       Minas Gerais (MG)                    MG
# 1760      Feminino          São Paulo (SP)                    SP
# 1427     Masculino  Rio Grande do Sul (RS)                    RS
# 892      Masculino          São Paulo (SP)                    SP
# 2209     Masculino     Rio de Janeiro (RJ)                    RJ
# 392      Masculino  Rio Grande do Sul (RS)                    RS
#
#      P1_E_B : Regiao Onde Mora P1_G_B : Regiao de Origem  \
# 2213                   Sudeste                       NaN
# 1761                   Sudeste                       NaN
# 2300                   Sudeste                       NaN
# 1850                  Exterior                       NaN
# 1897                   Sudeste                       NaN
# 1760                   Sudeste                   Sudeste
# 1427                       Sul                       NaN
# 892                    Sudeste                       NaN
# 2209                   Sudeste                       NaN
# 392                        Sul                       NaN
#
#       P1_G_C : Mudou de Estado? P1_H : Nivel de Ensino  \
# 2213                          0               Mestrado
# 1761                          0       Doutorado ou Phd
# 2300                          0  Graduação/Bacharelado
# 1850                          0               Mestrado
# 1897                          0          Pós-graduação
# 1760                          1               Mestrado
# 1427                          0          Pós-graduação
# 892                           0  Graduação/Bacharelado
# 2209                          0          Pós-graduação
# 392                           0          Pós-graduação
#
#                                 P1_I : Area de Formacao
# 2213  Computação / Engenharia de Software / Sistemas...
# 1761  Ciências Biológicas/Farmácia/Medicina/Área da ...
# 2300  Economia/ Administração / Contabilidade / Fina...
# 1850  Marketing / Publicidade / Comunicação / Jornal...
# 1897  Economia/ Administração / Contabilidade / Fina...
# 1760                                 Outras Engenharias
# 1427  Computação / Engenharia de Software / Sistemas...
# 892   Economia/ Administração / Contabilidade / Fina...
# 2209                                   Ciências Sociais
# 392   Computação / Engenharia de Software / Sistemas...

# %% [markdown]
# Com a visualização destes dados, notamos que a variável `Regiao de Origem` possui uma grande quantidade de valores inválidos (missing values). Por outro lado, as outras veriáveis estão bem preenchidas.
#
# Iniciando a análise, irei identificar os tipos de dados de cada uma das variáveis. Essa verificação inicial é essencial para análise, pois desta maneira, aplicarei as análises adequadas para cada variável.

# %%
#informações sobre as variáveis do conjunto P1
df_p1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2645 entries, 0 to 2644
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   P0 : ID                    2645 non-null   object
#  1   P1_A : Idade               2617 non-null   float64
#  2   P1_A_A : Faixa Idade       2645 non-null   object
#  3   P1_B : Genero              2645 non-null   object
#  4   P1_E : Estado Onde Mora    2609 non-null   object
#  5   P1_E_A : UF Onde Mora      2609 non-null   object
#  6   P1_E_B : Regiao Onde Mora  2645 non-null   object
#  7   P1_G_B : Regiao de Origem  484 non-null    object
#  8   P1_G_C : Mudou de Estado?  2645 non-null   int64
#  9   P1_H : Nivel de Ensino     2645 non-null   object
#  10  P1_I : Area de Formacao    2581 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 227.4+ KB

# %% [markdown]
# Podemos ver que novamente o Pandas teve dificuldades em identificar os tipos de dados e classificou como *dtype object*. As variáveis `Idade` e `Mudou de Estado` foram classificadas corretamente, mesmo que a variável relacionada ao Estado seja dicotômica e que não serão aplicados cálculos nestes dados, o Pandas identificou corretamente.
#
# Confirmando a hipotése inicial, a variável `Região de Origem` foi a mais afetada por valores inválidos com base no conjunto de perguntas P1.
#
# Fato curioso mas pouco relevante é que a pergunta `Idade` possui alguns valores inválidos. No entanto, a pergunta `Faixa de Idade` que está diretamente ligada com a anterior não possui valores inválidos. Esse mesmo comportamento se aplica a variável `Regiao Onde Mora`.
#
# **Vamos tratar dos tipos de dados!**

# %%
df_p1[['P0 : ID', 'P1_A_A : Faixa Idade', 'P1_B : Genero', 'P1_E : Estado Onde Mora']] = df_p1[['P0 : ID', 'P1_A_A : Faixa Idade', 'P1_B : Genero', 'P1_E : Estado Onde Mora']].astype('string')

# %%
df_p1[['P1_E_A : UF Onde Mora', 'P1_E_B : Regiao Onde Mora', 'P1_G_B : Regiao de Origem']] = df_p1[['P1_E_A : UF Onde Mora', 'P1_E_B : Regiao Onde Mora', 'P1_G_B : Regiao de Origem']].astype('string')

# %%
df_p1[['P1_H : Nivel de Ensino', 'P1_I : Area de Formacao']] = df_p1[['P1_H : Nivel de Ensino', 'P1_I : Area de Formacao']].astype('string')

# %%
df_p1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2645 entries, 0 to 2644
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   P0 : ID                    2645 non-null   string
#  1   P1_A : Idade               2617 non-null   float64
#  2   P1_A_A : Faixa Idade       2645 non-null   string
#  3   P1_B : Genero              2645 non-null   string
#  4   P1_E : Estado Onde Mora    2609 non-null   string
#  5   P1_E_A : UF Onde Mora      2609 non-null   string
#  6   P1_E_B : Regiao Onde Mora  2645 non-null   string
#  7   P1_G_B : Regiao de Origem  484 non-null    string
#  8   P1_G_C : Mudou de Estado?  2645 non-null   int64
#  9   P1_H : Nivel de Ensino     2645 non-null   string
#  10  P1_I : Area de Formacao    2581 non-null   string
# dtypes: float64(1), int64(1), string(9)
# memory usage: 227.4 KB

# %% [markdown]
# Antes de analisar cada uma dessas variáveis, vou analisar algumas estatísticas básicas que a função `.describe()` disponibiliza.

# %%
df_p1.describe(include='all')
# Out:
#                                  P0 : ID  P1_A : Idade P1_A_A : Faixa Idade  \
# count                               2645    2617.00000                 2645
# unique                              2641           NaN                    9
# top     yrhjxwscdfl516bibgi0kyrhait8fbnf           NaN                25-29
# freq                                   2           NaN                  833
# mean                                 NaN      31.15705                  NaN
# std                                  NaN       7.13062                  NaN
# min                                  NaN      18.00000                  NaN
# 25%                                  NaN      26.00000                  NaN
# 50%                                  NaN      30.00000                  NaN
# 75%                                  NaN      35.00000                  NaN
# max                                  NaN      54.00000                  NaN
#
#        P1_B : Genero P1_E : Estado Onde Mora P1_E_A : UF Onde Mora  \
# count           2645                    2609                  2609
# unique             3                      21                    21
# top        Masculino          São Paulo (SP)                    SP
# freq            2144                    1076                  1076
# mean             NaN                     NaN                   NaN
# std              NaN                     NaN                   NaN
# min              NaN                     NaN                   NaN
# 25%              NaN                     NaN                   NaN
# 50%              NaN                     NaN                   NaN
# 75%              NaN                     NaN                   NaN
# max              NaN                     NaN                   NaN
#
#        P1_E_B : Regiao Onde Mora P1_G_B : Regiao de Origem  \
# count                       2645                       484
# unique                         6                         5
# top                      Sudeste                   Sudeste
# freq                        1671                       222
# mean                         NaN                       NaN
# std                          NaN                       NaN
# min                          NaN                       NaN
# 25%                          NaN                       NaN
# 50%                          NaN                       NaN
# 75%                          NaN                       NaN
# max                          NaN                       NaN
#
#         P1_G_C : Mudou de Estado? P1_H : Nivel de Ensino  \
# count                 2645.000000                   2645
# unique                        NaN                      7
# top                           NaN  Graduação/Bacharelado
# freq                          NaN                    909
# mean                     0.182987                    NaN
# std                      0.386729                    NaN
# min                      0.000000                    NaN
# 25%                      0.000000                    NaN
# 50%                      0.000000                    NaN
# 75%                      0.000000                    NaN
# max                      1.000000                    NaN
#
#                                   P1_I : Area de Formacao
# count                                                2581
# unique                                                  9
# top     Computação / Engenharia de Software / Sistemas...
# freq                                                 1096
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %% [markdown]
# Com base nas estatísticas descritivas acima, conseguimos visualizar algumas predoominâncias com nos dados sociodemográficos.
#
# Informações coletadas da visualização acima:
#
# * ID's que aparecem mais de uma vez;
# * Média de idade de 31 anos;
# * As idades mais frequentes estão entre 25-29 anos;
# * Mais de 80% dos inidivíduos da pesquisa são do genêro masculino;
# * A maior parte dos indivíduos moram SP;
# * Região mais frequente é o Sudeste;
# * Boa parte dos indivíduos possuem o ensino superior, sendo graduação/bacharelado;
# * A área de formação mais frequente está relacionada com exatas.

# %%
df_p1['P0 : ID'].value_counts()
# Out:
# yrhjxwscdfl516bibgi0kyrhait8fbnf    2
# deptbnmlg4p0iuonwodept7eeluh5ov4    2
# 7lkav4o0fukny1644lc7lkav4o0c5wsb    2
# mdeq88ctdx127eztcxmdeq81poeki9ek    2
# qkx4q0ei90wcjxnqkx4q0j3xgf0zn13s    1
#                                    ..
# t198yi4rtuwu507i6ozjy2t198yjf19k    1
# t14vk15hwcx2w7t4r9t14vk8rybxsadv    1
# t0qlvyy5cd2z8q0liht0ql7d22gisdos    1
# t00leqn7a2b3b5l2gsby6pz7nt00leqn    1
# 037usz1h2yip96dgil4mhj037uszw1gk    1
# Name: P0 : ID, Length: 2641, dtype: int64

# %%
df_p1.loc[df_p1['P0 : ID'] == 'yrhjxwscdfl516bibgi0kyrhait8fbnf']
# Out:
#                              P0 : ID  P1_A : Idade P1_A_A : Faixa Idade  \
# 72  yrhjxwscdfl516bibgi0kyrhait8fbnf          30.0                30-34
# 73  yrhjxwscdfl516bibgi0kyrhait8fbnf          30.0                30-34
#
#    P1_B : Genero P1_E : Estado Onde Mora P1_E_A : UF Onde Mora  \
# 72     Masculino            Alagoas (AL)                    AL
# 73     Masculino            Alagoas (AL)                    AL
#
#    P1_E_B : Regiao Onde Mora P1_G_B : Regiao de Origem  \
# 72                  Nordeste                       NaN
# 73                  Nordeste                       NaN
#
#     P1_G_C : Mudou de Estado? P1_H : Nivel de Ensino  \
# 72                          0               Mestrado
# 73                          0               Mestrado
#
#                               P1_I : Area de Formacao
# 72  Computação / Engenharia de Software / Sistemas...
# 73  Computação / Engenharia de Software / Sistemas...
